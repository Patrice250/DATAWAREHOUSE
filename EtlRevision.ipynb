# %% [markdown]
# # Extract data

# %%
import pandas as pd

# %%
df = pd.read_excel("financial_sample.xlsx")
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 0        1618.5                    3          20      32370.0       0.00
# 1        1321.0                    3          20      26420.0       0.00
# 2        2178.0                    3          15      32670.0       0.00
# 3         888.0                    3          15      13320.0       0.00
# 4        2470.0                    3          15      37050.0       0.00
# ..          ...                  ...         ...          ...        ...
# 695      2475.0                  260         300     742500.0  111375.00
# 696       546.0                  260         300     163800.0   24570.00
# 697      1368.0                    5           7       9576.0    1436.40
# 698       723.0                   10           7       5061.0     759.15
# 699      1806.0                  250          12      21672.0    3250.80
#
#          Sales      COGS    Profit       Date  Month Number Month Name  Year
# 0     32370.00   16185.0  16185.00 2014-01-01             1    January  2014
# 1     26420.00   13210.0  13210.00 2014-01-01             1    January  2014
# 2     32670.00   21780.0  10890.00 2014-06-01             6       June  2014
# 3     13320.00    8880.0   4440.00 2014-06-01             6       June  2014
# 4     37050.00   24700.0  12350.00 2014-06-01             6       June  2014
# ..         ...       ...       ...        ...           ...        ...   ...
# 695  631125.00  618750.0  12375.00 2014-03-01             3      March  2014
# 696  139230.00  136500.0   2730.00 2014-10-01            10    October  2014
# 697    8139.60    6840.0   1299.60 2014-02-01             2   February  2014
# 698    4301.85    3615.0    686.85 2014-04-01             4      April  2014
# 699   18421.20    5418.0  13003.20 2014-05-01             5        May  2014
#
# [700 rows x 16 columns]

# %%
df1 = pd.read_excel("Electric_Vehicle_Population_Data.xlsx")
df1
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 1       JHMZC5F37M    Kitsap        Poulsbo    WA      98370.0        2021
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 3       1N4AZ0CP5D      King        Seattle    WA      98119.0        2013
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# ...            ...       ...            ...   ...          ...         ...
# 130438  7SAYGDEE6P    Pierce     Gig Harbor    WA      98335.0        2023
# 130439  1N4BZ1CV7N    Pierce         Tacoma    WA      98408.0        2022
# 130440  5YJYGDEE8M      King        Seattle    WA      98109.0        2021
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
# 130442  5YJ3E1EA5M    Pierce       Puyallup    WA      98375.0        2021
#
#           Make    Model                   Electric Vehicle Type  \
# 0        TESLA  MODEL X          Battery Electric Vehicle (BEV)
# 1        HONDA  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 3       NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 4        TESLA  MODEL S          Battery Electric Vehicle (BEV)
# ...        ...      ...                                     ...
# 130438   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 130439  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 130440   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 130441   TESLA  MODEL X          Battery Electric Vehicle (BEV)
# 130442   TESLA  MODEL 3          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible             238
# 1                 Clean Alternative Fuel Vehicle Eligible              47
# 2                 Clean Alternative Fuel Vehicle Eligible             220
# 3                 Clean Alternative Fuel Vehicle Eligible              75
# 4                 Clean Alternative Fuel Vehicle Eligible             210
# ...                                                   ...             ...
# 130438  Eligibility unknown as battery range has not b...               0
# 130439  Eligibility unknown as battery range has not b...               0
# 130440  Eligibility unknown as battery range has not b...               0
# 130441            Clean Alternative Fuel Vehicle Eligible             293
# 130442  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0               0                  14.0       141151601
# 1               0                  23.0       171566447
# 2               0                  36.0         9426525
# 3               0                  36.0       211807760
# 4               0                  22.0       185810306
# ...           ...                   ...             ...
# 130438          0                  26.0       231134102
# 130439          0                  29.0       185810943
# 130440          0                  36.0       176542418
# 130441          0                  10.0       102834938
# 130442          0                   2.0       180473639
#
#                                       Vehicle Location  \
# 0                          POINT (-120.56916 46.58514)
# 1                          POINT (-122.64681 47.73689)
# 2                          POINT (-122.40092 47.65908)
# 3                           POINT (-122.3684 47.64586)
# 4                          POINT (-122.75379 47.06316)
# ...                                                ...
# 130438   POINT (-122.58354539999999 47.32344880000005)
# 130439  POINT (-122.43810499999995 47.203220000000044)
# 130440                     POINT (-122.35022 47.63824)
# 130441                     POINT (-122.40049 48.23986)
# 130442                      POINT (-122.30116 47.1165)
#
#                                          Electric Utility  2020 Census Tract
# 0                                              PACIFICORP       5.307700e+10
# 1                                  PUGET SOUND ENERGY INC       5.303509e+10
# 2            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 3            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                                  PUGET SOUND ENERGY INC       5.306701e+10
# ...                                                   ...                ...
# 130438  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 130439  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 130440       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 130441  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.302997e+10
# 130442  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
#
# [130443 rows x 17 columns]

# %%
Date = df[['Month Number', 'Month Name', 'Year']]
Date = Date.rename(columns={'Month Number': 'd_date', 'Month Name': 'd_month','Year': 'd_year'})
Date
# Out:
#      d_date   d_month  d_year
# 0         1   January    2014
# 1         1   January    2014
# 2         6      June    2014
# 3         6      June    2014
# 4         6      June    2014
# ..      ...       ...     ...
# 695       3     March    2014
# 696      10   October    2014
# 697       2  February    2014
# 698       4     April    2014
# 699       5       May    2014
#
# [700 rows x 3 columns]

# %%
Sales = df[['Gross Sales','Sale Price']]
Sales = Sales.rename(columns={'Gross Sales': 'quantity', 'Sale Price': 'price'})
Sales
# Out:
#      quantity  price
# 0     32370.0     20
# 1     26420.0     20
# 2     32670.0     15
# 3     13320.0     15
# 4     37050.0     15
# ..        ...    ...
# 695  742500.0    300
# 696  163800.0    300
# 697    9576.0      7
# 698    5061.0      7
# 699   21672.0     12
#
# [700 rows x 2 columns]

# %%
Sales["total_sales"] = Sales["quantity"] * Sales["price"]
Sales
# Out:
#      quantity  price  total_sales
# 0     32370.0     20     647400.0
# 1     26420.0     20     528400.0
# 2     32670.0     15     490050.0
# 3     13320.0     15     199800.0
# 4     37050.0     15     555750.0
# ..        ...    ...          ...
# 695  742500.0    300  222750000.0
# 696  163800.0    300   49140000.0
# 697    9576.0      7      67032.0
# 698    5061.0      7      35427.0
# 699   21672.0     12     260064.0
#
# [700 rows x 3 columns]

# %%
Product = df1[['Electric Vehicle Type', 'Model']]
Product = Product.rename(columns={'Electric Vehicle Type': 'P_Name', 'Model':'category'})
Product
# Out:
#                                         P_Name category
# 0               Battery Electric Vehicle (BEV)  MODEL X
# 1       Plug-in Hybrid Electric Vehicle (PHEV)  CLARITY
# 2               Battery Electric Vehicle (BEV)  MODEL 3
# 3               Battery Electric Vehicle (BEV)     LEAF
# 4               Battery Electric Vehicle (BEV)  MODEL S
# ...                                        ...      ...
# 130438          Battery Electric Vehicle (BEV)  MODEL Y
# 130439          Battery Electric Vehicle (BEV)     LEAF
# 130440          Battery Electric Vehicle (BEV)  MODEL Y
# 130441          Battery Electric Vehicle (BEV)  MODEL X
# 130442          Battery Electric Vehicle (BEV)  MODEL 3
#
# [130443 rows x 2 columns]

# %%
Customer = df[['Segment', 'Country', ]]
Customer = Customer.rename(columns={'Segment': 'c_name', 'Country': 'city'})
Customer
# Out:
#                c_name                      city
# 0          Government                    Canada
# 1          Government                   Germany
# 2           Midmarket                    France
# 3           Midmarket                   Germany
# 4           Midmarket                    Mexico
# ..                ...                       ...
# 695    Small Business                    France
# 696    Small Business                    Mexico
# 697        Government                    Mexico
# 698        Government                    Canada
# 699  Channel Partners  United States of America
#
# [700 rows x 2 columns]

# %%
import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="etl_db"
)

# %%
cursor = mydb.cursor()

# %%
Date = Date.fillna('')
Date
# Out:
#      d_date   d_month  d_year
# 0         1   January    2014
# 1         1   January    2014
# 2         6      June    2014
# 3         6      June    2014
# 4         6      June    2014
# ..      ...       ...     ...
# 695       3     March    2014
# 696      10   October    2014
# 697       2  February    2014
# 698       4     April    2014
# 699       5       May    2014
#
# [700 rows x 3 columns]

# %%
insert_query = f"INSERT INTO date_tb ({','.join(Date.columns)}) VALUES ({','.join(['%s']*len(Date.columns))})"
    
for _, row in Date.iterrows():
    values = tuple(row)
    cursor.execute(insert_query, values)
    
mydb.commit()

# %%
Customer = Customer.fillna('')
Customer
# Out:
#                c_name                      city
# 0          Government                    Canada
# 1          Government                   Germany
# 2           Midmarket                    France
# 3           Midmarket                   Germany
# 4           Midmarket                    Mexico
# ..                ...                       ...
# 695    Small Business                    France
# 696    Small Business                    Mexico
# 697        Government                    Mexico
# 698        Government                    Canada
# 699  Channel Partners  United States of America
#
# [700 rows x 2 columns]

# %%
insert_query = f"INSERT INTO Customer_tb ({','.join(Customer.columns)}) VALUES ({','.join(['%s']*len(Customer.columns))})"
    
for _, row in Customer.iterrows():
    values = tuple(row)
    cursor.execute(insert_query, values)
    
mydb.commit()

# %%
Product = Product.fillna('')
Product
# Out:
#                                         P_Name category
# 0               Battery Electric Vehicle (BEV)  MODEL X
# 1       Plug-in Hybrid Electric Vehicle (PHEV)  CLARITY
# 2               Battery Electric Vehicle (BEV)  MODEL 3
# 3               Battery Electric Vehicle (BEV)     LEAF
# 4               Battery Electric Vehicle (BEV)  MODEL S
# ...                                        ...      ...
# 130438          Battery Electric Vehicle (BEV)  MODEL Y
# 130439          Battery Electric Vehicle (BEV)     LEAF
# 130440          Battery Electric Vehicle (BEV)  MODEL Y
# 130441          Battery Electric Vehicle (BEV)  MODEL X
# 130442          Battery Electric Vehicle (BEV)  MODEL 3
#
# [130443 rows x 2 columns]

# %%
insert_query = f"INSERT INTO product_tb ({','.join(Product.columns)}) VALUES ({','.join(['%s']*len(Product.columns))})"
    
for _, row in Product.iterrows():
    values = tuple(row)
    cursor.execute(insert_query, values)
    
mydb.commit()

# %%
# Execute SQL query
cursor.execute("SELECT * FROM product_tb")

rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Battery Electric Veh', 'MODEL X')
# (2, 'Plug-in Hybrid Elect', 'CLARITY')
# (3, 'Battery Electric Veh', 'MODEL 3')
# (4, 'Battery Electric Veh', 'LEAF')
# (5, 'Battery Electric Veh', 'MODEL S')
# (6, 'Plug-in Hybrid Elect', 'CLARITY')
# (7, 'Plug-in Hybrid Elect', 'FUSION')
# (8, 'Plug-in Hybrid Elect', 'Q5 E')
# (9, 'Plug-in Hybrid Elect', 'C-MAX')
# (10, 'Battery Electric Veh', 'MODEL S')
# (11, 'Battery Electric Veh', 'LEAF')
# (12, 'Battery Electric Veh', 'MODEL Y')
# (13, 'Battery Electric Veh', 'MODEL 3')
# (14, 'Battery Electric Veh', 'MODEL 3')
# (15, 'Plug-in Hybrid Elect', 'C-MAX')
# (16, 'Plug-in Hybrid Elect', 'NIRO')
# (17, 'Battery Electric Veh', 'LEAF')
# (18, 'Battery Electric Veh', 'MODEL S')
# (19, 'Plug-in Hybrid Elect', 'VOLT')
# (20, 'Battery Electric Veh', 'BOLT EV')
# (21, 'Battery Electric Veh', 'MODEL 3')
# (22, 'Battery Electric Veh', 'MODEL S')
# (23, 'Plug-in Hybrid Elect', 'VOLT')
# (24, 'Battery Electric Veh', 'LEAF')
# (25, 'Battery Electric Veh', 'MODEL S')
# (26, 'Battery Electric Veh', 'FORTWO')
# (27, 'Battery Electric Veh', 'LEAF')
# (28, 'Battery Electric Veh', 'LEAF')
# (29, 'Battery Electric Veh', 'MODEL 3')
# (30, 'Plug-in Hybrid Elect', 'X5')
# (31, 'Battery Electric Veh', 'MODEL Y')
# (32, 'Battery Electric Veh', 'MODEL 3')
# (33, 'Battery Electric Veh', 'MODEL 3')
# (34, 'Battery Electric Veh', 'LEAF')
# (35, 'Battery Electric Veh', 'LEAF')
# (36, 'Battery Electric Veh', 'MODEL 3')
# (37, 'Plug-in Hybrid Elect', 'SORENTO')
# (38, 'Battery Electric Veh', 'BOLT EV')
# (39, 'Battery Electric Veh', 'MODEL 3')
# (40, 'Battery Electric Veh', 'MODEL 3')
# (41, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (42, 'Plug-in Hybrid Elect', 'I3')
# (43, 'Battery Electric Veh', 'LEAF')
# (44, 'Battery Electric Veh', 'MODEL S')
# (45, 'Battery Electric Veh', 'LEAF')
# (46, 'Battery Electric Veh', 'MODEL X')
# (47, 'Battery Electric Veh', 'LEAF')
# (48, 'Battery Electric Veh', 'BOLT EV')
# (49, 'Battery Electric Veh', 'MODEL 3')
# (50, 'Battery Electric Veh', 'MODEL 3')
# (51, 'Plug-in Hybrid Elect', 'WRANGLER')
# (52, 'Battery Electric Veh', 'SPARK')
# (53, 'Battery Electric Veh', 'MODEL S')
# (54, 'Battery Electric Veh', 'MODEL S')
# (55, 'Battery Electric Veh', 'LEAF')
# (56, 'Battery Electric Veh', 'MODEL Y')
# (57, 'Battery Electric Veh', 'LEAF')
# (58, 'Battery Electric Veh', 'LEAF')
# (59, 'Plug-in Hybrid Elect', 'X5')
# (60, 'Battery Electric Veh', 'MODEL 3')
# (61, 'Battery Electric Veh', 'BOLT EV')
# (62, 'Battery Electric Veh', 'MODEL 3')
# (63, 'Battery Electric Veh', '500')
# (64, 'Battery Electric Veh', 'MODEL S')
# (65, 'Plug-in Hybrid Elect', 'C-MAX')
# (66, 'Battery Electric Veh', 'MODEL S')
# (67, 'Battery Electric Veh', 'MODEL X')
# (68, 'Battery Electric Veh', 'MODEL 3')
# (69, 'Plug-in Hybrid Elect', 'VOLT')
# (70, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (71, 'Plug-in Hybrid Elect', 'XC60')
# (72, 'Battery Electric Veh', 'MODEL 3')
# (73, 'Plug-in Hybrid Elect', 'VOLT')
# (74, 'Battery Electric Veh', 'LEAF')
# (75, 'Plug-in Hybrid Elect', 'VOLT')
# (76, 'Plug-in Hybrid Elect', 'VOLT')
# (77, 'Plug-in Hybrid Elect', 'XC90')
# (78, 'Battery Electric Veh', 'MODEL 3')
# (79, 'Battery Electric Veh', 'MODEL 3')
# (80, 'Battery Electric Veh', 'NIRO')
# (81, 'Battery Electric Veh', 'MODEL X')
# (82, 'Battery Electric Veh', 'MODEL 3')
# (83, 'Battery Electric Veh', 'NIRO')
# (84, 'Battery Electric Veh', 'MODEL 3')
# (85, 'Battery Electric Veh', 'BOLT EV')
# (86, 'Battery Electric Veh', 'MODEL 3')
# (87, 'Battery Electric Veh', 'SPARK')
# (88, 'Battery Electric Veh', 'FOCUS')
# (89, 'Plug-in Hybrid Elect', 'FUSION')
# (90, 'Battery Electric Veh', 'SOUL EV')
# (91, 'Battery Electric Veh', 'MODEL S')
# (92, 'Battery Electric Veh', 'MODEL X')
# (93, 'Battery Electric Veh', 'LEAF')
# (94, 'Plug-in Hybrid Elect', 'XC60')
# (95, 'Battery Electric Veh', 'LEAF')
# (96, 'Battery Electric Veh', 'LEAF')
# (97, 'Battery Electric Veh', 'MODEL 3')
# (98, 'Battery Electric Veh', 'NIRO')
# (99, 'Plug-in Hybrid Elect', 'FUSION')
# (100, 'Battery Electric Veh', 'MODEL Y')
# (101, 'Plug-in Hybrid Elect', 'A3')
# (102, 'Plug-in Hybrid Elect', 'VOLT')
# (103, 'Battery Electric Veh', 'LEAF')
# (104, 'Battery Electric Veh', 'MODEL 3')
# (105, 'Plug-in Hybrid Elect', 'X5')
# (106, 'Battery Electric Veh', 'MODEL 3')
# (107, 'Battery Electric Veh', 'LEAF')
# (108, 'Battery Electric Veh', 'MODEL 3')
# (109, 'Battery Electric Veh', 'MODEL S')
# (110, 'Plug-in Hybrid Elect', 'FUSION')
# (111, 'Plug-in Hybrid Elect', 'NIRO')
# (112, 'Battery Electric Veh', 'MODEL Y')
# (113, 'Battery Electric Veh', 'LEAF')
# (114, 'Battery Electric Veh', 'LEAF')
# (115, 'Battery Electric Veh', 'MODEL Y')
# (116, 'Plug-in Hybrid Elect', 'C-MAX')
# (117, 'Battery Electric Veh', 'MODEL X')
# (118, 'Battery Electric Veh', 'MODEL S')
# (119, 'Plug-in Hybrid Elect', 'WRANGLER')
# (120, 'Plug-in Hybrid Elect', 'PACIFICA')
# (121, 'Battery Electric Veh', 'LEAF')
# (122, 'Battery Electric Veh', 'LEAF')
# (123, 'Plug-in Hybrid Elect', 'C-MAX')
# (124, 'Plug-in Hybrid Elect', 'VOLT')
# (125, 'Plug-in Hybrid Elect', 'OPTIMA')
# (126, 'Battery Electric Veh', 'MODEL 3')
# (127, 'Plug-in Hybrid Elect', 'PACIFICA')
# (128, 'Battery Electric Veh', 'MODEL Y')
# (129, 'Plug-in Hybrid Elect', 'VOLT')
# (130, 'Battery Electric Veh', 'MODEL Y')
# (131, 'Battery Electric Veh', 'MODEL S')
# (132, 'Plug-in Hybrid Elect', 'NX')
# (133, 'Plug-in Hybrid Elect', 'WRANGLER')
# (134, 'Battery Electric Veh', 'BOLT EV')
# (135, 'Battery Electric Veh', 'MODEL 3')
# (136, 'Battery Electric Veh', 'MODEL 3')
# (137, 'Battery Electric Veh', 'LEAF')
# (138, 'Plug-in Hybrid Elect', 'PACIFICA')
# (139, 'Battery Electric Veh', 'MODEL S')
# (140, 'Plug-in Hybrid Elect', 'OPTIMA')
# (141, 'Battery Electric Veh', 'MODEL Y')
# (142, 'Battery Electric Veh', 'MODEL 3')
# (143, 'Battery Electric Veh', 'MODEL 3')
# (144, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (145, 'Plug-in Hybrid Elect', 'PRIUS PLUG-IN')
# (146, 'Battery Electric Veh', 'MODEL Y')
# (147, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (148, 'Battery Electric Veh', 'MODEL Y')
# (149, 'Battery Electric Veh', 'BOLT EUV')
# (150, 'Battery Electric Veh', 'MODEL Y')
# (151, 'Battery Electric Veh', 'MODEL Y')
# (152, 'Plug-in Hybrid Elect', 'CAYENNE')
# (153, 'Battery Electric Veh', 'BOLT EV')
# (154, 'Plug-in Hybrid Elect', 'WRANGLER')
# (155, 'Plug-in Hybrid Elect', 'ELR')
# (156, 'Plug-in Hybrid Elect', 'X3')
# (157, 'Battery Electric Veh', 'KONA ELECTRIC')
# (158, 'Battery Electric Veh', 'MODEL Y')
# (159, 'Battery Electric Veh', 'MODEL X')
# (160, 'Battery Electric Veh', 'MODEL Y')
# (161, 'Plug-in Hybrid Elect', 'VOLT')
# (162, 'Plug-in Hybrid Elect', '530E')
# (163, 'Battery Electric Veh', 'MODEL S')
# (164, 'Battery Electric Veh', 'EQB-CLASS')
# (165, 'Battery Electric Veh', 'MODEL Y')
# (166, 'Battery Electric Veh', 'MODEL X')
# (167, 'Plug-in Hybrid Elect', 'WRANGLER')
# (168, 'Battery Electric Veh', 'MODEL 3')
# (169, 'Battery Electric Veh', 'MODEL Y')
# (170, 'Battery Electric Veh', 'MODEL 3')
# (171, 'Battery Electric Veh', 'MODEL 3')
# (172, 'Battery Electric Veh', 'LEAF')
# (173, 'Battery Electric Veh', 'MODEL Y')
# (174, 'Plug-in Hybrid Elect', 'NIRO')
# (175, 'Battery Electric Veh', 'MODEL Y')
# (176, 'Battery Electric Veh', 'LEAF')
# (177, 'Battery Electric Veh', 'MODEL 3')
# (178, 'Battery Electric Veh', 'MODEL Y')
# (179, 'Battery Electric Veh', 'MODEL S')
# (180, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (181, 'Battery Electric Veh', 'LEAF')
# (182, 'Battery Electric Veh', 'R1T')
# (183, 'Plug-in Hybrid Elect', 'WRANGLER')
# (184, 'Battery Electric Veh', 'MODEL 3')
# (185, 'Battery Electric Veh', 'FORTWO')
# (186, 'Battery Electric Veh', 'MODEL 3')
# (187, 'Battery Electric Veh', 'TRANSIT')
# (188, 'Battery Electric Veh', 'MODEL Y')
# (189, 'Plug-in Hybrid Elect', 'VOLT')
# (190, 'Battery Electric Veh', 'MODEL Y')
# (191, 'Battery Electric Veh', 'E-GOLF')
# (192, 'Battery Electric Veh', 'MODEL S')
# (193, 'Battery Electric Veh', 'MODEL Y')
# (194, 'Battery Electric Veh', 'MODEL Y')
# (195, 'Battery Electric Veh', 'MODEL 3')
# (196, 'Battery Electric Veh', 'MODEL Y')
# (197, 'Battery Electric Veh', 'MODEL Y')
# (198, 'Battery Electric Veh', 'BOLT EV')
# (199, 'Battery Electric Veh', 'MODEL S')
# (200, 'Battery Electric Veh', 'MODEL Y')
# (201, 'Battery Electric Veh', 'ID.4')
# (202, 'Battery Electric Veh', 'MODEL X')
# (203, 'Battery Electric Veh', 'LEAF')
# (204, 'Battery Electric Veh', 'MODEL S')
# (205, 'Battery Electric Veh', 'BOLT EV')
# (206, 'Battery Electric Veh', 'LEAF')
# (207, 'Battery Electric Veh', 'LEAF')
# (208, 'Battery Electric Veh', 'LEAF')
# (209, 'Battery Electric Veh', 'MODEL 3')
# (210, 'Battery Electric Veh', 'MODEL 3')
# (211, 'Battery Electric Veh', 'LEAF')
# (212, 'Battery Electric Veh', 'MODEL Y')
# (213, 'Battery Electric Veh', 'MODEL X')
# (214, 'Battery Electric Veh', 'MODEL Y')
# (215, 'Battery Electric Veh', 'BOLT EV')
# (216, 'Plug-in Hybrid Elect', 'WRANGLER')
# (217, 'Battery Electric Veh', 'LEAF')
# (218, 'Battery Electric Veh', 'MODEL 3')
# (219, 'Battery Electric Veh', 'MODEL Y')
# (220, 'Battery Electric Veh', 'MODEL Y')
# (221, 'Plug-in Hybrid Elect', 'WRANGLER')
# (222, 'Battery Electric Veh', 'LEAF')
# (223, 'Battery Electric Veh', 'MODEL 3')
# (224, 'Battery Electric Veh', 'FORTWO ELECTRIC DRIV')
# (225, 'Battery Electric Veh', 'MODEL 3')
# (226, 'Battery Electric Veh', 'MODEL 3')
# (227, 'Battery Electric Veh', 'MODEL 3')
# (228, 'Battery Electric Veh', 'NIRO')
# (229, 'Battery Electric Veh', 'MODEL Y')
# (230, 'Battery Electric Veh', 'E-GOLF')
# (231, 'Battery Electric Veh', 'LEAF')
# (232, 'Battery Electric Veh', 'MODEL 3')
# (233, 'Plug-in Hybrid Elect', 'NIRO')
# (234, 'Plug-in Hybrid Elect', 'C-MAX')
# (235, 'Battery Electric Veh', 'MODEL 3')
# (236, 'Battery Electric Veh', 'BOLT EV')
# (237, 'Battery Electric Veh', 'MODEL S')
# (238, 'Battery Electric Veh', 'MODEL Y')
# (239, 'Battery Electric Veh', 'MODEL 3')
# (240, 'Battery Electric Veh', 'MODEL Y')
# (241, 'Battery Electric Veh', 'I-PACE')
# (242, 'Battery Electric Veh', 'SOUL EV')
# (243, 'Battery Electric Veh', 'MODEL 3')
# (244, 'Battery Electric Veh', 'ID.4')
# (245, 'Battery Electric Veh', 'LEAF')
# (246, 'Battery Electric Veh', 'MODEL 3')
# (247, 'Battery Electric Veh', 'MODEL 3')
# (248, 'Plug-in Hybrid Elect', 'AVIATOR')
# (249, 'Battery Electric Veh', 'MODEL 3')
# (250, 'Battery Electric Veh', 'LEAF')
# (251, 'Battery Electric Veh', 'MODEL 3')
# (252, 'Battery Electric Veh', 'MODEL 3')
# (253, 'Battery Electric Veh', 'TAYCAN')
# (254, 'Battery Electric Veh', 'MODEL S')
# (255, 'Battery Electric Veh', 'E-TRON')
# (256, 'Battery Electric Veh', 'MODEL Y')
# (257, 'Battery Electric Veh', 'MODEL Y')
# (258, 'Battery Electric Veh', 'MODEL 3')
# (259, 'Plug-in Hybrid Elect', 'FUSION')
# (260, 'Battery Electric Veh', 'MODEL S')
# (261, 'Battery Electric Veh', 'MODEL 3')
# (262, 'Battery Electric Veh', 'MODEL X')
# (263, 'Battery Electric Veh', 'MODEL Y')
# (264, 'Battery Electric Veh', 'ID.4')
# (265, 'Plug-in Hybrid Elect', 'PACIFICA')
# (266, 'Plug-in Hybrid Elect', 'C-CLASS')
# (267, 'Plug-in Hybrid Elect', 'OUTLANDER')
# (268, 'Battery Electric Veh', 'I3')
# (269, 'Battery Electric Veh', 'MODEL Y')
# (270, 'Battery Electric Veh', 'SOUL')
# (271, 'Plug-in Hybrid Elect', 'SONATA')
# (272, 'Plug-in Hybrid Elect', 'VOLT')
# (273, 'Battery Electric Veh', 'MODEL S')
# (274, 'Battery Electric Veh', 'LEAF')
# (275, 'Battery Electric Veh', 'MODEL 3')
# (276, 'Plug-in Hybrid Elect', 'GRAND CHEROKEE')
# (277, 'Plug-in Hybrid Elect', 'VOLT')
# (278, 'Plug-in Hybrid Elect', '530E')
# (279, 'Battery Electric Veh', 'MODEL 3')
# (280, 'Battery Electric Veh', 'MODEL 3')
# (281, 'Plug-in Hybrid Elect', 'WRANGLER')
# (282, 'Battery Electric Veh', 'MODEL X')
# (283, 'Battery Electric Veh', 'LEAF')
# (284, 'Battery Electric Veh', 'MODEL S')
# (285, 'Battery Electric Veh', 'LEAF')
# (286, 'Battery Electric Veh', 'LEAF')
# (287, 'Plug-in Hybrid Elect', 'VOLT')
# (288, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (289, 'Battery Electric Veh', 'MODEL 3')
# (290, 'Battery Electric Veh', 'TRANSIT')
# (291, 'Plug-in Hybrid Elect', 'PACIFICA')
# (292, 'Plug-in Hybrid Elect', 'WRANGLER')
# (293, 'Battery Electric Veh', 'MODEL X')
# (294, 'Plug-in Hybrid Elect', 'PRIUS PLUG-IN')
# (295, 'Battery Electric Veh', 'MODEL Y')
# (296, 'Battery Electric Veh', 'MODEL 3')
# (297, 'Battery Electric Veh', 'BOLT EV')
# (298, 'Plug-in Hybrid Elect', 'VOLT')
# (299, 'Battery Electric Veh', 'BOLT EV')
# (300, 'Battery Electric Veh', 'MODEL X')
# (301, 'Plug-in Hybrid Elect', 'VOLT')
# (302, 'Battery Electric Veh', 'MODEL Y')
# (303, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (304, 'Battery Electric Veh', 'MODEL 3')
# (305, 'Battery Electric Veh', 'R1T')
# (306, 'Battery Electric Veh', 'MODEL 3')
# (307, 'Plug-in Hybrid Elect', 'SPORTAGE')
# (308, 'Battery Electric Veh', 'NIRO')
# (309, 'Plug-in Hybrid Elect', 'XC90')
# (310, 'Plug-in Hybrid Elect', 'I3')
# (311, 'Battery Electric Veh', 'MODEL 3')
# (312, 'Battery Electric Veh', 'MODEL X')
# (313, 'Battery Electric Veh', 'MODEL S')
# (314, 'Plug-in Hybrid Elect', 'OUTLANDER')
# (315, 'Battery Electric Veh', 'MODEL Y')
# (316, 'Battery Electric Veh', 'IONIQ 5')
# (317, 'Battery Electric Veh', 'MODEL Y')
# (318, 'Battery Electric Veh', 'MODEL Y')
# (319, 'Battery Electric Veh', 'MODEL Y')
# (320, 'Battery Electric Veh', 'MODEL 3')
# (321, 'Battery Electric Veh', 'MODEL Y')
# (322, 'Plug-in Hybrid Elect', 'XC90')
# (323, 'Battery Electric Veh', 'E-TRON')
# (324, 'Battery Electric Veh', 'LEAF')
# (325, 'Battery Electric Veh', 'LEAF')
# (326, 'Battery Electric Veh', 'MODEL 3')
# (327, 'Plug-in Hybrid Elect', 'A3')
# (328, 'Plug-in Hybrid Elect', 'X5')
# (329, 'Battery Electric Veh', 'MODEL Y')
# (330, 'Battery Electric Veh', '500')
# (331, 'Battery Electric Veh', 'LEAF')
# (332, 'Plug-in Hybrid Elect', 'I3')
# (333, 'Battery Electric Veh', 'BOLT EV')
# (334, 'Battery Electric Veh', 'BOLT EV')
# (335, 'Battery Electric Veh', 'FORTWO ELECTRIC DRIV')
# (336, 'Battery Electric Veh', 'MODEL Y')
# (337, 'Battery Electric Veh', 'MODEL 3')
# (338, 'Battery Electric Veh', 'MODEL Y')
# (339, 'Battery Electric Veh', 'MODEL 3')
# (340, 'Battery Electric Veh', 'MODEL S')
# (341, 'Battery Electric Veh', 'R1T')
# (342, 'Battery Electric Veh', 'MODEL 3')
# (343, 'Battery Electric Veh', 'MODEL 3')
# (344, 'Plug-in Hybrid Elect', 'I3')
# (345, 'Battery Electric Veh', 'MODEL 3')
# (346, 'Plug-in Hybrid Elect', 'X5')
# (347, 'Battery Electric Veh', 'MODEL 3')
# (348, 'Plug-in Hybrid Elect', 'NX')
# (349, 'Battery Electric Veh', 'MODEL Y')
# (350, 'Battery Electric Veh', 'E-TRON')
# (351, 'Battery Electric Veh', 'E-TRON')
# (352, 'Battery Electric Veh', 'MODEL S')
# (353, 'Battery Electric Veh', 'BOLT EV')
# (354, 'Battery Electric Veh', 'LEAF')
# (355, 'Battery Electric Veh', 'LEAF')
# (356, 'Plug-in Hybrid Elect', 'VOLT')
# (357, 'Battery Electric Veh', 'EV6')
# (358, 'Battery Electric Veh', 'BOLT EV')
# (359, 'Battery Electric Veh', 'MODEL 3')
# (360, 'Battery Electric Veh', 'R1T')
# (361, 'Battery Electric Veh', 'NIRO')
# (362, 'Battery Electric Veh', 'ID.4')
# (363, 'Battery Electric Veh', 'LEAF')
# (364, 'Battery Electric Veh', 'MODEL Y')
# (365, 'Battery Electric Veh', 'LEAF')
# (366, 'Battery Electric Veh', 'MODEL Y')
# (367, 'Battery Electric Veh', 'BOLT EV')
# (368, 'Battery Electric Veh', 'MODEL 3')
# (369, 'Battery Electric Veh', 'MODEL 3')
# (370, 'Battery Electric Veh', 'MODEL Y')
# (371, 'Battery Electric Veh', 'MODEL 3')
# (372, 'Battery Electric Veh', 'LEAF')
# (373, 'Battery Electric Veh', 'EQS-CLASS SEDAN')
# (374, 'Battery Electric Veh', 'MODEL Y')
# (375, 'Battery Electric Veh', 'MODEL S')
# (376, 'Battery Electric Veh', 'MODEL Y')
# (377, 'Plug-in Hybrid Elect', 'PRIUS PLUG-IN')
# (378, 'Battery Electric Veh', 'MODEL Y')
# (379, 'Battery Electric Veh', 'MODEL Y')
# (380, 'Plug-in Hybrid Elect', 'XC60')
# (381, 'Battery Electric Veh', 'MODEL S')
# (382, 'Battery Electric Veh', 'MODEL Y')
# (383, 'Battery Electric Veh', 'MODEL S')
# (384, 'Battery Electric Veh', 'LEAF')
# (385, 'Plug-in Hybrid Elect', 'C-MAX')
# (386, 'Battery Electric Veh', 'LEAF')
# (387, 'Battery Electric Veh', 'LEAF')
# (388, 'Battery Electric Veh', 'MODEL 3')
# (389, 'Battery Electric Veh', 'MODEL 3')
# (390, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (391, 'Battery Electric Veh', 'MODEL Y')
# (392, 'Battery Electric Veh', 'MODEL Y')
# (393, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (394, 'Battery Electric Veh', 'MODEL Y')
# (395, 'Battery Electric Veh', 'SOUL EV')
# (396, 'Battery Electric Veh', 'MODEL Y')
# (397, 'Plug-in Hybrid Elect', 'WRANGLER')
# (398, 'Battery Electric Veh', 'R1S')
# (399, 'Battery Electric Veh', 'MODEL 3')
# (400, 'Battery Electric Veh', 'EV6')
# (401, 'Plug-in Hybrid Elect', 'XC60')
# (402, 'Battery Electric Veh', 'MODEL Y')
# (403, 'Battery Electric Veh', 'BOLT EV')
# (404, 'Battery Electric Veh', 'MODEL X')
# (405, 'Plug-in Hybrid Elect', 'PACIFICA')
# (406, 'Battery Electric Veh', 'LEAF')
# (407, 'Battery Electric Veh', 'LEAF')
# (408, 'Battery Electric Veh', 'LEAF')
# (409, 'Battery Electric Veh', 'MODEL Y')
# (410, 'Battery Electric Veh', 'SOUL')
# (411, 'Battery Electric Veh', 'KONA ELECTRIC')
# (412, 'Battery Electric Veh', 'IX')
# (413, 'Plug-in Hybrid Elect', 'NIRO')
# (414, 'Battery Electric Veh', 'MODEL Y')
# (415, 'Battery Electric Veh', 'MODEL 3')
# (416, 'Battery Electric Veh', 'MODEL Y')
# (417, 'Battery Electric Veh', 'LEAF')
# (418, 'Battery Electric Veh', 'KONA')
# (419, 'Battery Electric Veh', 'LEAF')
# (420, 'Battery Electric Veh', 'MODEL Y')
# (421, 'Battery Electric Veh', 'LEAF')
# (422, 'Battery Electric Veh', 'MODEL Y')
# (423, 'Battery Electric Veh', 'MODEL 3')
# (424, 'Battery Electric Veh', 'IX')
# (425, 'Battery Electric Veh', 'MODEL Y')
# (426, 'Battery Electric Veh', 'E-GOLF')
# (427, 'Battery Electric Veh', 'MODEL 3')
# (428, 'Plug-in Hybrid Elect', 'WRANGLER')
# (429, 'Battery Electric Veh', 'MODEL Y')
# (430, 'Battery Electric Veh', 'MODEL Y')
# (431, 'Plug-in Hybrid Elect', 'Q5 E')
# (432, 'Plug-in Hybrid Elect', 'WRANGLER')
# (433, 'Battery Electric Veh', 'BOLT EV')
# (434, 'Plug-in Hybrid Elect', 'VOLT')
# (435, 'Battery Electric Veh', 'MODEL 3')
# (436, 'Battery Electric Veh', 'LEAF')
# (437, 'Battery Electric Veh', 'MODEL Y')
# (438, 'Battery Electric Veh', 'MODEL 3')
# (439, 'Battery Electric Veh', 'LEAF')
# (440, 'Battery Electric Veh', 'MODEL S')
# (441, 'Battery Electric Veh', 'MODEL Y')
# (442, 'Battery Electric Veh', 'MODEL 3')
# (443, 'Battery Electric Veh', 'BOLT EV')
# (444, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (445, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (446, 'Battery Electric Veh', 'MODEL 3')
# (447, 'Battery Electric Veh', 'MODEL Y')
# (448, 'Plug-in Hybrid Elect', 'PACIFICA')
# (449, 'Battery Electric Veh', 'MODEL S')
# (450, 'Battery Electric Veh', 'MODEL 3')
# (451, 'Plug-in Hybrid Elect', 'C-MAX')
# (452, 'Battery Electric Veh', 'LEAF')
# (453, 'Battery Electric Veh', 'MODEL Y')
# (454, 'Plug-in Hybrid Elect', 'I3')
# (455, 'Battery Electric Veh', 'MODEL Y')
# (456, 'Battery Electric Veh', 'MODEL 3')
# (457, 'Battery Electric Veh', 'MODEL 3')
# (458, 'Battery Electric Veh', 'MODEL 3')
# (459, 'Battery Electric Veh', 'MODEL S')
# (460, 'Battery Electric Veh', 'MODEL 3')
# (461, 'Plug-in Hybrid Elect', 'I3')
# (462, 'Battery Electric Veh', 'LEAF')
# (463, 'Battery Electric Veh', 'MODEL S')
# (464, 'Battery Electric Veh', 'LEAF')
# (465, 'Plug-in Hybrid Elect', 'I3')
# (466, 'Battery Electric Veh', 'MODEL X')
# (467, 'Plug-in Hybrid Elect', 'WRANGLER')
# (468, 'Battery Electric Veh', 'MODEL 3')
# (469, 'Battery Electric Veh', 'LEAF')
# (470, 'Battery Electric Veh', 'MODEL 3')
# (471, 'Battery Electric Veh', 'BOLT EUV')
# (472, 'Battery Electric Veh', 'MODEL 3')
# (473, 'Battery Electric Veh', 'R1T')
# (474, 'Battery Electric Veh', 'EV6')
# (475, 'Plug-in Hybrid Elect', 'I8')
# (476, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (477, 'Plug-in Hybrid Elect', 'I3')
# (478, 'Battery Electric Veh', 'LEAF')
# (479, 'Battery Electric Veh', 'MODEL Y')
# (480, 'Battery Electric Veh', 'FORTWO ELECTRIC DRIV')
# (481, 'Battery Electric Veh', 'MODEL Y')
# (482, 'Plug-in Hybrid Elect', 'VOLT')
# (483, 'Plug-in Hybrid Elect', 'PACIFICA')
# (484, 'Plug-in Hybrid Elect', 'XC90')
# (485, 'Battery Electric Veh', 'MODEL 3')
# (486, 'Battery Electric Veh', 'MODEL Y')
# (487, 'Battery Electric Veh', 'MODEL 3')
# (488, 'Plug-in Hybrid Elect', 'FUSION')
# (489, 'Battery Electric Veh', 'MODEL 3')
# (490, 'Battery Electric Veh', 'MODEL Y')
# (491, 'Plug-in Hybrid Elect', 'WRANGLER')
# (492, 'Plug-in Hybrid Elect', 'VOLT')
# (493, 'Battery Electric Veh', 'ID.4')
# (494, 'Battery Electric Veh', 'MODEL 3')
# (495, 'Battery Electric Veh', 'MODEL 3')
# (496, 'Battery Electric Veh', 'MODEL Y')
# (497, 'Battery Electric Veh', 'MODEL X')
# (498, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (499, 'Battery Electric Veh', 'LEAF')
# (500, 'Plug-in Hybrid Elect', 'PACIFICA')
# (501, 'Battery Electric Veh', 'LEAF')
# (502, 'Battery Electric Veh', 'MODEL S')
# (503, 'Battery Electric Veh', 'MODEL Y')
# (504, 'Battery Electric Veh', 'MODEL Y')
# (505, 'Plug-in Hybrid Elect', '330E')
# (506, 'Battery Electric Veh', 'MODEL Y')
# (507, 'Battery Electric Veh', 'MODEL 3')
# (508, 'Battery Electric Veh', 'LEAF')
# (509, 'Battery Electric Veh', 'MODEL 3')
# (510, 'Battery Electric Veh', 'EQS-CLASS SEDAN')
# (511, 'Battery Electric Veh', 'NIRO')
# (512, 'Plug-in Hybrid Elect', 'VOLT')
# (513, 'Plug-in Hybrid Elect', 'X3')
# (514, 'Plug-in Hybrid Elect', 'X5')
# (515, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (516, 'Battery Electric Veh', 'LEAF')
# (517, 'Battery Electric Veh', 'MODEL S')
# (518, 'Plug-in Hybrid Elect', 'VOLT')
# (519, 'Battery Electric Veh', 'NIRO')
# (520, 'Battery Electric Veh', 'MODEL 3')
# (521, 'Plug-in Hybrid Elect', 'COUNTRYMAN')
# (522, 'Battery Electric Veh', 'MODEL X')
# (523, 'Battery Electric Veh', 'MODEL Y')
# (524, 'Battery Electric Veh', 'LEAF')
# (525, 'Plug-in Hybrid Elect', 'WRANGLER')
# (526, 'Battery Electric Veh', 'R1S')
# (527, 'Battery Electric Veh', 'BOLT EV')
# (528, 'Plug-in Hybrid Elect', 'NIRO')
# (529, 'Battery Electric Veh', 'EV6')
# (530, 'Battery Electric Veh', 'MODEL Y')
# (531, 'Battery Electric Veh', 'MODEL X')
# (532, 'Battery Electric Veh', 'MODEL Y')
# (533, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (534, 'Carretera', 'Canada')
# (535, 'Carretera', 'Germany')
# (536, 'Carretera', 'France')
# (537, 'Carretera', 'Germany')
# (538, 'Carretera', 'Mexico')
# (539, 'Carretera', 'Germany')
# (540, 'Montana', 'Germany')
# (541, 'Montana', 'Canada')
# (542, 'Montana', 'France')
# (543, 'Montana', 'Germany')
# (544, 'Montana', 'Mexico')
# (545, 'Montana', 'Canada')
# (546, 'Montana', 'Mexico')
# (547, 'Montana', 'Germany')
# (548, 'Montana', 'Canada')
# (549, 'Montana', 'United States of Ame')
# (550, 'Paseo', 'Canada')
# (551, 'Paseo', 'Mexico')
# (552, 'Paseo', 'Canada')
# (553, 'Paseo', 'Germany')
# (554, 'Paseo', 'Germany')
# (555, 'Paseo', 'Mexico')
# (556, 'Paseo', 'France')
# (557, 'Paseo', 'Mexico')
# (558, 'Paseo', 'Mexico')
# (559, 'Paseo', 'United States of Ame')
# (560, 'Paseo', 'Canada')
# (561, 'Paseo', 'United States of Ame')
# (562, 'Paseo', 'Canada')
# (563, 'Paseo', 'Canada')
# (564, 'Paseo', 'Germany')
# (565, 'Velo', 'Mexico')
# (566, 'Velo', 'France')
# (567, 'Velo', 'Germany')
# (568, 'Velo', 'Germany')
# (569, 'Velo', 'Germany')
# (570, 'Velo', 'United States of Ame')
# (571, 'Velo', 'Canada')
# (572, 'VTT', 'Canada')
# (573, 'VTT', 'Germany')
# (574, 'VTT', 'France')
# (575, 'VTT', 'Germany')
# (576, 'VTT', 'France')
# (577, 'VTT', 'France')
# (578, 'VTT', 'Canada')
# (579, 'Amarilla', 'France')
# (580, 'Amarilla', 'United States of Ame')
# (581, 'Amarilla', 'Germany')
# (582, 'Amarilla', 'France')
# (583, 'Amarilla', 'Germany')
# (584, 'Amarilla', 'United States of Ame')
# (585, 'Amarilla', 'United States of Ame')
# (586, 'Amarilla', 'United States of Ame')
# (587, 'Paseo', 'France')
# (588, 'Paseo', 'France')
# (589, 'Paseo', 'France')
# (590, 'Velo', 'France')
# (591, 'VTT', 'Canada')
# (592, 'Carretera', 'United States of Ame')
# (593, 'Carretera', 'Mexico')
# (594, 'Carretera', 'United States of Ame')
# (595, 'Carretera', 'Canada')
# (596, 'Carretera', 'United States of Ame')
# (597, 'Carretera', 'France')
# (598, 'Carretera', 'Germany')
# (599, 'Carretera', 'Mexico')
# (600, 'Carretera', 'Mexico')
# (601, 'Carretera', 'France')
# (602, 'Montana', 'Mexico')
# (603, 'Montana', 'United States of Ame')
# (604, 'Montana', 'France')
# (605, 'Montana', 'Canada')
# (606, 'Montana', 'United States of Ame')
# (607, 'Montana', 'United States of Ame')
# (608, 'Paseo', 'United States of Ame')
# (609, 'Paseo', 'United States of Ame')
# (610, 'Paseo', 'United States of Ame')
# (611, 'Paseo', 'France')
# (612, 'Paseo', 'Mexico')
# (613, 'Paseo', 'Germany')
# (614, 'Paseo', 'Germany')
# (615, 'Paseo', 'United States of Ame')
# (616, 'Paseo', 'France')
# (617, 'Velo', 'France')
# (618, 'Velo', 'Mexico')
# (619, 'Velo', 'Canada')
# (620, 'Velo', 'United States of Ame')
# (621, 'Velo', 'Canada')
# (622, 'VTT', 'Germany')
# (623, 'VTT', 'Canada')
# (624, 'VTT', 'United States of Ame')
# (625, 'VTT', 'France')
# (626, 'VTT', 'Germany')
# (627, 'VTT', 'Mexico')
# (628, 'VTT', 'Mexico')
# (629, 'VTT', 'France')
# (630, 'Amarilla', 'United States of Ame')
# (631, 'Amarilla', 'France')
# (632, 'Carretera', 'Canada')
# (633, 'Carretera', 'Canada')
# (634, 'Carretera', 'Germany')
# (635, 'Carretera', 'France')
# (636, 'Carretera', 'Canada')
# (637, 'Montana', 'United States of Ame')
# (638, 'Montana', 'United States of Ame')
# (639, 'Montana', 'Mexico')
# (640, 'Montana', 'Mexico')
# (641, 'Paseo', 'Canada')
# (642, 'Paseo', 'France')
# (643, 'Paseo', 'Germany')
# (644, 'Paseo', 'United States of Ame')
# (645, 'Paseo', 'Mexico')
# (646, 'Paseo', 'Canada')
# (647, 'Paseo', 'Germany')
# (648, 'Paseo', 'Mexico')
# (649, 'Paseo', 'France')
# (650, 'Paseo', 'Canada')
# (651, 'Paseo', 'Canada')
# (652, 'Paseo', 'Canada')
# (653, 'Paseo', 'United States of Ame')
# (654, 'Paseo', 'United States of Ame')
# (655, 'Paseo', 'France')
# (656, 'Paseo', 'Mexico')
# (657, 'Velo', 'United States of Ame')
# (658, 'Velo', 'Germany')
# (659, 'Velo', 'Germany')
# (660, 'Velo', 'Germany')
# (661, 'Velo', 'Mexico')
# (662, 'Velo', 'France')
# (663, 'Velo', 'Mexico')
# (664, 'Velo', 'Mexico')
# (665, 'VTT', 'Mexico')
# (666, 'VTT', 'Germany')
# (667, 'VTT', 'Germany')
# (668, 'VTT', 'Canada')
# (669, 'VTT', 'United States of Ame')
# (670, 'VTT', 'Mexico')
# (671, 'Amarilla', 'Germany')
# (672, 'Amarilla', 'Mexico')
# (673, 'Amarilla', 'Germany')
# (674, 'Amarilla', 'Germany')
# (675, 'Amarilla', 'United States of Ame')
# (676, 'Amarilla', 'France')
# (677, 'Amarilla', 'Canada')
# (678, 'Carretera', 'France')
# (679, 'Carretera', 'Germany')
# (680, 'Carretera', 'Germany')
# (681, 'Carretera', 'United States of Ame')
# (682, 'Carretera', 'Canada')
# (683, 'Montana', 'Germany')
# (684, 'Montana', 'France')
# (685, 'Montana', 'France')
# (686, 'Montana', 'Germany')
# (687, 'Montana', 'France')
# (688, 'Montana', 'Germany')
# (689, 'Paseo', 'France')
# (690, 'Paseo', 'Canada')
# (691, 'Paseo', 'France')
# (692, 'Paseo', 'Germany')
# (693, 'Paseo', 'Germany')
# (694, 'Paseo', 'United States of Ame')
# (695, 'Paseo', 'Canada')
# (696, 'Paseo', 'Germany')
# (697, 'Paseo', 'France')
# (698, 'Paseo', 'Germany')
# (699, 'Velo', 'Canada')
# (700, 'VTT', 'United States of Ame')
# (701, 'VTT', 'Mexico')
# (702, 'VTT', 'Germany')
# (703, 'VTT', 'Canada')
# (704, 'VTT', 'Mexico')
# (705, 'VTT', 'Germany')
# (706, 'Carretera', 'Canada')
# (707, 'Paseo', 'Mexico')
# (708, 'Velo', 'Canada')
# (709, 'VTT', 'Germany')
# (710, 'Montana', 'Mexico')
# (711, 'Paseo', 'Mexico')
# (712, 'Paseo', 'France')
# (713, 'Velo', 'United States of Ame')
# (714, 'Carretera', 'Canada')
# (715, 'Carretera', 'Germany')
# (716, 'Carretera', 'United States of Ame')
# (717, 'Montana', 'Canada')
# (718, 'Montana', 'Germany')
# (719, 'Montana', 'Canada')
# (720, 'Montana', 'Germany')
# (721, 'Montana', 'Mexico')
# (722, 'Paseo', 'Canada')
# (723, 'Paseo', 'Germany')
# (724, 'Paseo', 'Germany')
# (725, 'Paseo', 'United States of Ame')
# (726, 'Paseo', 'United States of Ame')
# (727, 'Paseo', 'France')
# (728, 'Paseo', 'Canada')
# (729, 'Paseo', 'Canada')
# (730, 'Paseo', 'United States of Ame')
# (731, 'Paseo', 'United States of Ame')
# (732, 'Paseo', 'Mexico')
# (733, 'Paseo', 'United States of Ame')
# (734, 'Paseo', 'Mexico')
# (735, 'Velo', 'United States of Ame')
# (736, 'Velo', 'Canada')
# (737, 'Velo', 'France')
# (738, 'VTT', 'France')
# (739, 'VTT', 'United States of Ame')
# (740, 'VTT', 'France')
# (741, 'VTT', 'Mexico')
# (742, 'Amarilla', 'Mexico')
# (743, 'Amarilla', 'Mexico')
# (744, 'Amarilla', 'Germany')
# (745, 'Amarilla', 'United States of Ame')
# (746, 'Amarilla', 'Canada')
# (747, 'Montana', 'Germany')
# (748, 'Paseo', 'Germany')
# (749, 'Paseo', 'Canada')
# (750, 'Paseo', 'Mexico')
# (751, 'Paseo', 'Canada')
# (752, 'Velo', 'Canada')
# (753, 'VTT', 'Mexico')
# (754, 'Amarilla', 'Mexico')
# (755, 'Amarilla', 'Mexico')
# (756, 'Amarilla', 'Germany')
# (757, 'Carretera', 'France')
# (758, 'Carretera', 'Germany')
# (759, 'Carretera', 'France')
# (760, 'Carretera', 'United States of Ame')
# (761, 'Carretera', 'Germany')
# (762, 'Carretera', 'Mexico')
# (763, 'Carretera', 'United States of Ame')
# (764, 'Carretera', 'France')
# (765, 'Montana', 'France')
# (766, 'Montana', 'United States of Ame')
# (767, 'Montana', 'Mexico')
# (768, 'Montana', 'Germany')
# (769, 'Montana', 'Mexico')
# (770, 'Paseo', 'France')
# (771, 'Paseo', 'United States of Ame')
# (772, 'Paseo', 'France')
# (773, 'Paseo', 'Mexico')
# (774, 'Paseo', 'United States of Ame')
# (775, 'Paseo', 'United States of Ame')
# (776, 'Paseo', 'United States of Ame')
# (777, 'Paseo', 'France')
# (778, 'Paseo', 'Canada')
# (779, 'Paseo', 'Canada')
# (780, 'Paseo', 'United States of Ame')
# (781, 'Paseo', 'France')
# (782, 'Paseo', 'Canada')
# (783, 'Paseo', 'United States of Ame')
# (784, 'Paseo', 'France')
# (785, 'Paseo', 'Germany')
# (786, 'Velo', 'United States of Ame')
# (787, 'Velo', 'Mexico')
# (788, 'Velo', 'Germany')
# (789, 'Velo', 'United States of Ame')
# (790, 'Velo', 'United States of Ame')
# (791, 'Velo', 'France')
# (792, 'Velo', 'United States of Ame')
# (793, 'Velo', 'France')
# (794, 'Velo', 'France')
# (795, 'Velo', 'Germany')
# (796, 'VTT', 'Canada')
# (797, 'VTT', 'United States of Ame')
# (798, 'VTT', 'Germany')
# (799, 'VTT', 'United States of Ame')
# (800, 'VTT', 'United States of Ame')
# (801, 'VTT', 'France')
# (802, 'Amarilla', 'Germany')
# (803, 'Amarilla', 'Canada')
# (804, 'Amarilla', 'Canada')
# (805, 'Amarilla', 'Germany')
# (806, 'Paseo', 'France')
# (807, 'Carretera', 'United States of Ame')
# (808, 'Carretera', 'Canada')
# (809, 'Carretera', 'Mexico')
# (810, 'Carretera', 'Canada')
# (811, 'Carretera', 'United States of Ame')
# (812, 'Carretera', 'United States of Ame')
# (813, 'Carretera', 'Germany')
# (814, 'Montana', 'Mexico')
# (815, 'Montana', 'Germany')
# (816, 'Montana', 'France')
# (817, 'Montana', 'United States of Ame')
# (818, 'Paseo', 'France')
# (819, 'Paseo', 'Canada')
# (820, 'Paseo', 'United States of Ame')
# (821, 'Velo', 'Canada')
# (822, 'Velo', 'United States of Ame')
# (823, 'Velo', 'Germany')
# (824, 'Velo', 'France')
# (825, 'Velo', 'Mexico')
# (826, 'Velo', 'France')
# (827, 'Velo', 'France')
# (828, 'VTT', 'Canada')
# (829, 'VTT', 'Mexico')
# (830, 'VTT', 'France')
# (831, 'VTT', 'Mexico')
# (832, 'VTT', 'Canada')
# (833, 'Amarilla', 'France')
# (834, 'Amarilla', 'Mexico')
# (835, 'Amarilla', 'United States of Ame')
# (836, 'Amarilla', 'France')
# (837, 'Amarilla', 'France')
# (838, 'Montana', 'France')
# (839, 'Paseo', 'United States of Ame')
# (840, 'Paseo', 'Germany')
# (841, 'Paseo', 'United States of Ame')
# (842, 'Paseo', 'France')
# (843, 'Velo', 'Germany')
# (844, 'Velo', 'Mexico')
# (845, 'VTT', 'United States of Ame')
# (846, 'Carretera', 'Mexico')
# (847, 'Carretera', 'Canada')
# (848, 'Carretera', 'Mexico')
# (849, 'Montana', 'Mexico')
# (850, 'Montana', 'France')
# (851, 'Paseo', 'France')
# (852, 'Velo', 'Canada')
# (853, 'Velo', 'Canada')
# (854, 'Velo', 'United States of Ame')
# (855, 'Velo', 'Canada')
# (856, 'VTT', 'France')
# (857, 'VTT', 'Germany')
# (858, 'VTT', 'Canada')
# (859, 'Amarilla', 'Canada')
# (860, 'Carretera', 'United States of Ame')
# (861, 'Carretera', 'France')
# (862, 'Carretera', 'France')
# (863, 'Montana', 'France')
# (864, 'Montana', 'France')
# (865, 'Montana', 'Germany')
# (866, 'Paseo', 'Canada')
# (867, 'Paseo', 'France')
# (868, 'Paseo', 'Germany')
# (869, 'Paseo', 'France')
# (870, 'Paseo', 'United States of Ame')
# (871, 'Paseo', 'France')
# (872, 'Paseo', 'Germany')
# (873, 'Paseo', 'Canada')
# (874, 'Paseo', 'Mexico')
# (875, 'Paseo', 'Germany')
# (876, 'Velo', 'France')
# (877, 'Velo', 'Mexico')
# (878, 'Velo', 'Germany')
# (879, 'Velo', 'France')
# (880, 'Velo', 'United States of Ame')
# (881, 'Velo', 'United States of Ame')
# (882, 'Velo', 'Germany')
# (883, 'VTT', 'Canada')
# (884, 'VTT', 'France')
# (885, 'VTT', 'Mexico')
# (886, 'Amarilla', 'Canada')
# (887, 'Amarilla', 'France')
# (888, 'Amarilla', 'Germany')
# (889, 'Amarilla', 'Canada')
# (890, 'Amarilla', 'United States of Ame')
# (891, 'Montana', 'Canada')
# (892, 'Montana', 'United States of Ame')
# (893, 'Paseo', 'Canada')
# (894, 'Amarilla', 'United States of Ame')
# (895, 'Carretera', 'Mexico')
# (896, 'Carretera', 'France')
# (897, 'Carretera', 'Mexico')
# (898, 'Montana', 'France')
# (899, 'Montana', 'Canada')
# (900, 'Montana', 'Germany')
# (901, 'Montana', 'France')
# (902, 'Montana', 'Canada')
# (903, 'Montana', 'Germany')
# (904, 'Paseo', 'Mexico')
# (905, 'Paseo', 'Germany')
# (906, 'Paseo', 'Germany')
# (907, 'Paseo', 'Germany')
# (908, 'Paseo', 'Mexico')
# (909, 'Paseo', 'United States of Ame')
# (910, 'Paseo', 'Germany')
# (911, 'Paseo', 'Germany')
# (912, 'Paseo', 'Germany')
# (913, 'Paseo', 'Mexico')
# (914, 'Paseo', 'Germany')
# (915, 'Paseo', 'Mexico')
# (916, 'Paseo', 'Mexico')
# (917, 'Velo', 'Canada')
# (918, 'Velo', 'United States of Ame')
# (919, 'Velo', 'Germany')
# (920, 'Velo', 'France')
# (921, 'Velo', 'Mexico')
# (922, 'VTT', 'France')
# (923, 'VTT', 'Germany')
# (924, 'VTT', 'France')
# (925, 'VTT', 'Germany')
# (926, 'VTT', 'Canada')
# (927, 'VTT', 'United States of Ame')
# (928, 'Amarilla', 'Canada')
# (929, 'Amarilla', 'United States of Ame')
# (930, 'Amarilla', 'Germany')
# (931, 'Amarilla', 'Mexico')
# (932, 'Amarilla', 'Germany')
# (933, 'Amarilla', 'Germany')
# (934, 'Amarilla', 'Mexico')
# (935, 'Amarilla', 'Mexico')
# (936, 'VTT', 'United States of Ame')
# (937, 'Carretera', 'Canada')
# (938, 'Carretera', 'Mexico')
# (939, 'Montana', 'Canada')
# (940, 'Montana', 'France')
# (941, 'Montana', 'France')
# (942, 'Montana', 'Canada')
# (943, 'Montana', 'France')
# (944, 'Montana', 'Canada')
# (945, 'Montana', 'United States of Ame')
# (946, 'Montana', 'Germany')
# (947, 'Paseo', 'Mexico')
# (948, 'Paseo', 'Mexico')
# (949, 'Paseo', 'United States of Ame')
# (950, 'Paseo', 'Canada')
# (951, 'Paseo', 'France')
# (952, 'Paseo', 'Mexico')
# (953, 'Paseo', 'France')
# (954, 'Paseo', 'Germany')
# (955, 'Paseo', 'United States of Ame')
# (956, 'Velo', 'Mexico')
# (957, 'Velo', 'Canada')
# (958, 'Velo', 'Germany')
# (959, 'Velo', 'Canada')
# (960, 'Velo', 'Mexico')
# (961, 'Velo', 'Canada')
# (962, 'VTT', 'United States of Ame')
# (963, 'VTT', 'Germany')
# (964, 'VTT', 'United States of Ame')
# (965, 'VTT', 'Germany')
# (966, 'VTT', 'United States of Ame')
# (967, 'VTT', 'France')
# (968, 'VTT', 'France')
# (969, 'VTT', 'Mexico')
# (970, 'Amarilla', 'United States of Ame')
# (971, 'Amarilla', 'Canada')
# (972, 'Amarilla', 'Germany')
# (973, 'Amarilla', 'Mexico')
# (974, 'Carretera', 'Germany')
# (975, 'Carretera', 'Canada')
# (976, 'Carretera', 'Germany')
# (977, 'Carretera', 'Mexico')
# (978, 'Paseo', 'United States of Ame')
# (979, 'Paseo', 'Mexico')
# (980, 'Paseo', 'Germany')
# (981, 'Velo', 'France')
# (982, 'Velo', 'Mexico')
# (983, 'VTT', 'Germany')
# (984, 'VTT', 'France')
# (985, 'VTT', 'Mexico')
# (986, 'Amarilla', 'Mexico')
# (987, 'Amarilla', 'Canada')
# (988, 'Amarilla', 'France')
# (989, 'Carretera', 'United States of Ame')
# (990, 'Montana', 'United States of Ame')
# (991, 'Paseo', 'United States of Ame')
# (992, 'Carretera', 'United States of Ame')
# (993, 'Carretera', 'France')
# (994, 'Montana', 'United States of Ame')
# (995, 'Montana', 'United States of Ame')
# (996, 'Montana', 'France')
# (997, 'Paseo', 'France')
# (998, 'Paseo', 'Mexico')
# (999, 'Paseo', 'France')
# (1000, 'Paseo', 'Germany')
# (1001, 'Velo', 'Germany')
# (1002, 'Velo', 'Germany')
# (1003, 'Velo', 'United States of Ame')
# (1004, 'Velo', 'France')
# (1005, 'Velo', 'United States of Ame')
# (1006, 'Velo', 'United States of Ame')
# (1007, 'Velo', 'Germany')
# (1008, 'Velo', 'Germany')
# (1009, 'Velo', 'Canada')
# (1010, 'Velo', 'France')
# (1011, 'VTT', 'Mexico')
# (1012, 'VTT', 'Mexico')
# (1013, 'VTT', 'United States of Ame')
# (1014, 'VTT', 'Mexico')
# (1015, 'VTT', 'United States of Ame')
# (1016, 'VTT', 'France')
# (1017, 'VTT', 'Canada')
# (1018, 'VTT', 'Germany')
# (1019, 'Amarilla', 'United States of Ame')
# (1020, 'Amarilla', 'Canada')
# (1021, 'Amarilla', 'United States of Ame')
# (1022, 'Amarilla', 'Canada')
# (1023, 'Amarilla', 'Mexico')
# (1024, 'Amarilla', 'Germany')
# (1025, 'Amarilla', 'Canada')
# (1026, 'Amarilla', 'France')
# (1027, 'Amarilla', 'France')
# (1028, 'Carretera', 'France')
# (1029, 'Paseo', 'France')
# (1030, 'Paseo', 'France')
# (1031, 'Velo', 'Canada')
# (1032, 'Velo', 'Germany')
# (1033, 'VTT', 'United States of Ame')
# (1034, 'VTT', 'Mexico')
# (1035, 'Amarilla', 'United States of Ame')
# (1036, 'Amarilla', 'Germany')
# (1037, 'Carretera', 'Canada')
# (1038, 'Carretera', 'Germany')
# (1039, 'Carretera', 'Germany')
# (1040, 'Carretera', 'France')
# (1041, 'Carretera', 'Canada')
# (1042, 'Carretera', 'Mexico')
# (1043, 'Montana', 'Germany')
# (1044, 'Montana', 'Germany')
# (1045, 'Montana', 'Mexico')
# (1046, 'Paseo', 'Canada')
# (1047, 'Paseo', 'Mexico')
# (1048, 'Paseo', 'Canada')
# (1049, 'Paseo', 'Canada')
# (1050, 'Paseo', 'France')
# (1051, 'Paseo', 'Canada')
# (1052, 'Paseo', 'Mexico')
# (1053, 'Paseo', 'France')
# (1054, 'Paseo', 'Germany')
# (1055, 'Paseo', 'Canada')
# (1056, 'Velo', 'France')
# (1057, 'Velo', 'Mexico')
# (1058, 'Velo', 'Mexico')
# (1059, 'Velo', 'Canada')
# (1060, 'VTT', 'France')
# (1061, 'VTT', 'Mexico')
# (1062, 'VTT', 'Canada')
# (1063, 'Amarilla', 'Germany')
# (1064, 'Amarilla', 'Mexico')
# (1065, 'Amarilla', 'France')
# (1066, 'Amarilla', 'Mexico')
# (1067, 'Amarilla', 'Mexico')
# (1068, 'Amarilla', 'Mexico')
# (1069, 'Paseo', 'United States of Ame')
# (1070, 'Carretera', 'Mexico')
# (1071, 'Carretera', 'Canada')
# (1072, 'Carretera', 'Mexico')
# (1073, 'Carretera', 'Canada')
# (1074, 'Montana', 'United States of Ame')
# (1075, 'Montana', 'France')
# (1076, 'Montana', 'Mexico')
# (1077, 'Montana', 'Canada')
# (1078, 'Montana', 'Mexico')
# (1079, 'Montana', 'France')
# (1080, 'Paseo', 'United States of Ame')
# (1081, 'Paseo', 'Mexico')
# (1082, 'Paseo', 'Mexico')
# (1083, 'Paseo', 'Mexico')
# (1084, 'Paseo', 'Mexico')
# (1085, 'Paseo', 'France')
# (1086, 'Paseo', 'Germany')
# (1087, 'Paseo', 'Mexico')
# (1088, 'Paseo', 'Mexico')
# (1089, 'Paseo', 'Mexico')
# (1090, 'Paseo', 'Mexico')
# (1091, 'Velo', 'Mexico')
# (1092, 'Velo', 'United States of Ame')
# (1093, 'Velo', 'Mexico')
# (1094, 'VTT', 'Canada')
# (1095, 'VTT', 'France')
# (1096, 'VTT', 'Canada')
# (1097, 'VTT', 'United States of Ame')
# (1098, 'VTT', 'United States of Ame')
# (1099, 'VTT', 'Mexico')
# (1100, 'Amarilla', 'United States of Ame')
# (1101, 'Amarilla', 'France')
# (1102, 'Amarilla', 'Canada')
# (1103, 'Amarilla', 'United States of Ame')
# (1104, 'Carretera', 'France')
# (1105, 'Montana', 'Mexico')
# (1106, 'Paseo', 'Germany')
# (1107, 'VTT', 'France')
# (1108, 'VTT', 'Germany')
# (1109, 'Amarilla', 'Canada')
# (1110, 'Carretera', 'United States of Ame')
# (1111, 'VTT', 'United States of Ame')
# (1112, 'Carretera', 'Canada')
# (1113, 'Carretera', 'France')
# (1114, 'Carretera', 'Germany')
# (1115, 'Montana', 'United States of Ame')
# (1116, 'Montana', 'United States of Ame')
# (1117, 'Montana', 'Mexico')
# (1118, 'Montana', 'Mexico')
# (1119, 'Montana', 'Canada')
# (1120, 'Paseo', 'United States of Ame')
# (1121, 'Paseo', 'Germany')
# (1122, 'Paseo', 'United States of Ame')
# (1123, 'Paseo', 'Germany')
# (1124, 'Paseo', 'Canada')
# (1125, 'Paseo', 'Canada')
# (1126, 'Paseo', 'Mexico')
# (1127, 'Paseo', 'France')
# (1128, 'Paseo', 'Canada')
# (1129, 'Paseo', 'Canada')
# (1130, 'Paseo', 'Germany')
# (1131, 'Paseo', 'Germany')
# (1132, 'Velo', 'France')
# (1133, 'Velo', 'Canada')
# (1134, 'Velo', 'France')
# (1135, 'Velo', 'Mexico')
# (1136, 'Velo', 'Germany')
# (1137, 'Velo', 'Mexico')
# (1138, 'Velo', 'Mexico')
# (1139, 'Velo', 'Germany')
# (1140, 'VTT', 'Canada')
# (1141, 'VTT', 'Canada')
# (1142, 'Amarilla', 'Canada')
# (1143, 'Amarilla', 'France')
# (1144, 'Amarilla', 'Mexico')
# (1145, 'Amarilla', 'Germany')
# (1146, 'Carretera', 'Mexico')
# (1147, 'Carretera', 'United States of Ame')
# (1148, 'Carretera', 'United States of Ame')
# (1149, 'Carretera', 'Germany')
# (1150, 'Montana', 'France')
# (1151, 'Montana', 'United States of Ame')
# (1152, 'Paseo', 'Germany')
# (1153, 'Paseo', 'Canada')
# (1154, 'Paseo', 'United States of Ame')
# (1155, 'Paseo', 'France')
# (1156, 'VTT', 'Germany')
# (1157, 'Amarilla', 'France')
# (1158, 'Amarilla', 'United States of Ame')
# (1159, 'Carretera', 'Mexico')
# (1160, 'Carretera', 'France')
# (1161, 'Carretera', 'Canada')
# (1162, 'Carretera', 'United States of Ame')
# (1163, 'Carretera', 'Germany')
# (1164, 'Carretera', 'Canada')
# (1165, 'Carretera', 'Mexico')
# (1166, 'Montana', 'Canada')
# (1167, 'Montana', 'Germany')
# (1168, 'Montana', 'Canada')
# (1169, 'Montana', 'Canada')
# (1170, 'Montana', 'Mexico')
# (1171, 'Montana', 'Canada')
# (1172, 'Paseo', 'Mexico')
# (1173, 'Paseo', 'Canada')
# (1174, 'Paseo', 'Canada')
# (1175, 'Paseo', 'United States of Ame')
# (1176, 'Paseo', 'France')
# (1177, 'Paseo', 'Canada')
# (1178, 'Paseo', 'Canada')
# (1179, 'Paseo', 'United States of Ame')
# (1180, 'Paseo', 'France')
# (1181, 'Velo', 'Mexico')
# (1182, 'Velo', 'United States of Ame')
# (1183, 'Velo', 'United States of Ame')
# (1184, 'Velo', 'Canada')
# (1185, 'Velo', 'Germany')
# (1186, 'VTT', 'Mexico')
# (1187, 'VTT', 'United States of Ame')
# (1188, 'VTT', 'Canada')
# (1189, 'VTT', 'Canada')
# (1190, 'VTT', 'United States of Ame')
# (1191, 'VTT', 'France')
# (1192, 'Amarilla', 'Canada')
# (1193, 'Amarilla', 'United States of Ame')
# (1194, 'Amarilla', 'France')
# (1195, 'Amarilla', 'Canada')
# (1196, 'Amarilla', 'United States of Ame')
# (1197, 'Amarilla', 'France')
# (1198, 'Amarilla', 'Mexico')
# (1199, 'Amarilla', 'Mexico')
# (1200, 'Carretera', 'France')
# (1201, 'Carretera', 'Germany')
# (1202, 'Carretera', 'Germany')
# (1203, 'Montana', 'Mexico')
# (1204, 'Paseo', 'Germany')
# (1205, 'Paseo', 'Canada')
# (1206, 'Paseo', 'Mexico')
# (1207, 'Paseo', 'Mexico')
# (1208, 'Paseo', 'Canada')
# (1209, 'Paseo', 'United States of Ame')
# (1210, 'Paseo', 'Germany')
# (1211, 'Paseo', 'Germany')
# (1212, 'Paseo', 'United States of Ame')
# (1213, 'Paseo', 'Mexico')
# (1214, 'Paseo', 'United States of Ame')
# (1215, 'Paseo', 'France')
# (1216, 'Velo', 'Mexico')
# (1217, 'Velo', 'France')
# (1218, 'Velo', 'France')
# (1219, 'Velo', 'United States of Ame')
# (1220, 'Velo', 'United States of Ame')
# (1221, 'Velo', 'United States of Ame')
# (1222, 'VTT', 'Canada')
# (1223, 'VTT', 'Germany')
# (1224, 'VTT', 'United States of Ame')
# (1225, 'VTT', 'Germany')
# (1226, 'VTT', 'Canada')
# (1227, 'VTT', 'Germany')
# (1228, 'VTT', 'France')
# (1229, 'Amarilla', 'France')
# (1230, 'Amarilla', 'Mexico')
# (1231, 'Montana', 'Mexico')
# (1232, 'Paseo', 'Canada')
# (1233, 'VTT', 'United States of Ame')
# (1234, 'Carretera', 'Canada')
# (1235, 'Carretera', 'Germany')
# (1236, 'Carretera', 'France')
# (1237, 'Carretera', 'Germany')
# (1238, 'Carretera', 'Mexico')
# (1239, 'Carretera', 'Germany')
# (1240, 'Montana', 'Germany')
# (1241, 'Montana', 'Canada')
# (1242, 'Montana', 'France')
# (1243, 'Montana', 'Germany')
# (1244, 'Montana', 'Mexico')
# (1245, 'Montana', 'Canada')
# (1246, 'Montana', 'Mexico')
# (1247, 'Montana', 'Germany')
# (1248, 'Montana', 'Canada')
# (1249, 'Montana', 'United States of Ame')
# (1250, 'Paseo', 'Canada')
# (1251, 'Paseo', 'Mexico')
# (1252, 'Paseo', 'Canada')
# (1253, 'Paseo', 'Germany')
# (1254, 'Paseo', 'Germany')
# (1255, 'Paseo', 'Mexico')
# (1256, 'Paseo', 'France')
# (1257, 'Paseo', 'Mexico')
# (1258, 'Paseo', 'Mexico')
# (1259, 'Paseo', 'United States of Ame')
# (1260, 'Paseo', 'Canada')
# (1261, 'Paseo', 'United States of Ame')
# (1262, 'Paseo', 'Canada')
# (1263, 'Paseo', 'Canada')
# (1264, 'Paseo', 'Germany')
# (1265, 'Velo', 'Mexico')
# (1266, 'Velo', 'France')
# (1267, 'Velo', 'Germany')
# (1268, 'Velo', 'Germany')
# (1269, 'Velo', 'Germany')
# (1270, 'Velo', 'United States of Ame')
# (1271, 'Velo', 'Canada')
# (1272, 'VTT', 'Canada')
# (1273, 'VTT', 'Germany')
# (1274, 'VTT', 'France')
# (1275, 'VTT', 'Germany')
# (1276, 'VTT', 'France')
# (1277, 'VTT', 'France')
# (1278, 'VTT', 'Canada')
# (1279, 'Amarilla', 'France')
# (1280, 'Amarilla', 'United States of Ame')
# (1281, 'Amarilla', 'Germany')
# (1282, 'Amarilla', 'France')
# (1283, 'Amarilla', 'Germany')
# (1284, 'Amarilla', 'United States of Ame')
# (1285, 'Amarilla', 'United States of Ame')
# (1286, 'Amarilla', 'United States of Ame')
# (1287, 'Paseo', 'France')
# (1288, 'Paseo', 'France')
# (1289, 'Paseo', 'France')
# (1290, 'Velo', 'France')
# (1291, 'VTT', 'Canada')
# (1292, 'Carretera', 'United States of Ame')
# (1293, 'Carretera', 'Mexico')
# (1294, 'Carretera', 'United States of Ame')
# (1295, 'Carretera', 'Canada')
# (1296, 'Carretera', 'United States of Ame')
# (1297, 'Carretera', 'France')
# (1298, 'Carretera', 'Germany')
# (1299, 'Carretera', 'Mexico')
# (1300, 'Carretera', 'Mexico')
# (1301, 'Carretera', 'France')
# (1302, 'Montana', 'Mexico')
# (1303, 'Montana', 'United States of Ame')
# (1304, 'Montana', 'France')
# (1305, 'Montana', 'Canada')
# (1306, 'Montana', 'United States of Ame')
# (1307, 'Montana', 'United States of Ame')
# (1308, 'Paseo', 'United States of Ame')
# (1309, 'Paseo', 'United States of Ame')
# (1310, 'Paseo', 'United States of Ame')
# (1311, 'Paseo', 'France')
# (1312, 'Paseo', 'Mexico')
# (1313, 'Paseo', 'Germany')
# (1314, 'Paseo', 'Germany')
# (1315, 'Paseo', 'United States of Ame')
# (1316, 'Paseo', 'France')
# (1317, 'Velo', 'France')
# (1318, 'Velo', 'Mexico')
# (1319, 'Velo', 'Canada')
# (1320, 'Velo', 'United States of Ame')
# (1321, 'Velo', 'Canada')
# (1322, 'VTT', 'Germany')
# (1323, 'VTT', 'Canada')
# (1324, 'VTT', 'United States of Ame')
# (1325, 'VTT', 'France')
# (1326, 'VTT', 'Germany')
# (1327, 'VTT', 'Mexico')
# (1328, 'VTT', 'Mexico')
# (1329, 'VTT', 'France')
# (1330, 'Amarilla', 'United States of Ame')
# (1331, 'Amarilla', 'France')
# (1332, 'Carretera', 'Canada')
# (1333, 'Carretera', 'Canada')
# (1334, 'Carretera', 'Germany')
# (1335, 'Carretera', 'France')
# (1336, 'Carretera', 'Canada')
# (1337, 'Montana', 'United States of Ame')
# (1338, 'Montana', 'United States of Ame')
# (1339, 'Montana', 'Mexico')
# (1340, 'Montana', 'Mexico')
# (1341, 'Paseo', 'Canada')
# (1342, 'Paseo', 'France')
# (1343, 'Paseo', 'Germany')
# (1344, 'Paseo', 'United States of Ame')
# (1345, 'Paseo', 'Mexico')
# (1346, 'Paseo', 'Canada')
# (1347, 'Paseo', 'Germany')
# (1348, 'Paseo', 'Mexico')
# (1349, 'Paseo', 'France')
# (1350, 'Paseo', 'Canada')
# (1351, 'Paseo', 'Canada')
# (1352, 'Paseo', 'Canada')
# (1353, 'Paseo', 'United States of Ame')
# (1354, 'Paseo', 'United States of Ame')
# (1355, 'Paseo', 'France')
# (1356, 'Paseo', 'Mexico')
# (1357, 'Velo', 'United States of Ame')
# (1358, 'Velo', 'Germany')
# (1359, 'Velo', 'Germany')
# (1360, 'Velo', 'Germany')
# (1361, 'Velo', 'Mexico')
# (1362, 'Velo', 'France')
# (1363, 'Velo', 'Mexico')
# (1364, 'Velo', 'Mexico')
# (1365, 'VTT', 'Mexico')
# (1366, 'VTT', 'Germany')
# (1367, 'VTT', 'Germany')
# (1368, 'VTT', 'Canada')
# (1369, 'VTT', 'United States of Ame')
# (1370, 'VTT', 'Mexico')
# (1371, 'Amarilla', 'Germany')
# (1372, 'Amarilla', 'Mexico')
# (1373, 'Amarilla', 'Germany')
# (1374, 'Amarilla', 'Germany')
# (1375, 'Amarilla', 'United States of Ame')
# (1376, 'Amarilla', 'France')
# (1377, 'Amarilla', 'Canada')
# (1378, 'Carretera', 'France')
# (1379, 'Carretera', 'Germany')
# (1380, 'Carretera', 'Germany')
# (1381, 'Carretera', 'United States of Ame')
# (1382, 'Carretera', 'Canada')
# (1383, 'Montana', 'Germany')
# (1384, 'Montana', 'France')
# (1385, 'Montana', 'France')
# (1386, 'Montana', 'Germany')
# (1387, 'Montana', 'France')
# (1388, 'Montana', 'Germany')
# (1389, 'Paseo', 'France')
# (1390, 'Paseo', 'Canada')
# (1391, 'Paseo', 'France')
# (1392, 'Paseo', 'Germany')
# (1393, 'Paseo', 'Germany')
# (1394, 'Paseo', 'United States of Ame')
# (1395, 'Paseo', 'Canada')
# (1396, 'Paseo', 'Germany')
# (1397, 'Paseo', 'France')
# (1398, 'Paseo', 'Germany')
# (1399, 'Velo', 'Canada')
# (1400, 'VTT', 'United States of Ame')
# (1401, 'VTT', 'Mexico')
# (1402, 'VTT', 'Germany')
# (1403, 'VTT', 'Canada')
# (1404, 'VTT', 'Mexico')
# (1405, 'VTT', 'Germany')
# (1406, 'Carretera', 'Canada')
# (1407, 'Paseo', 'Mexico')
# (1408, 'Velo', 'Canada')
# (1409, 'VTT', 'Germany')
# (1410, 'Montana', 'Mexico')
# (1411, 'Paseo', 'Mexico')
# (1412, 'Paseo', 'France')
# (1413, 'Velo', 'United States of Ame')
# (1414, 'Carretera', 'Canada')
# (1415, 'Carretera', 'Germany')
# (1416, 'Carretera', 'United States of Ame')
# (1417, 'Montana', 'Canada')
# (1418, 'Montana', 'Germany')
# (1419, 'Montana', 'Canada')
# (1420, 'Montana', 'Germany')
# (1421, 'Montana', 'Mexico')
# (1422, 'Paseo', 'Canada')
# (1423, 'Paseo', 'Germany')
# (1424, 'Paseo', 'Germany')
# (1425, 'Paseo', 'United States of Ame')
# (1426, 'Paseo', 'United States of Ame')
# (1427, 'Paseo', 'France')
# (1428, 'Paseo', 'Canada')
# (1429, 'Paseo', 'Canada')
# (1430, 'Paseo', 'United States of Ame')
# (1431, 'Paseo', 'United States of Ame')
# (1432, 'Paseo', 'Mexico')
# (1433, 'Paseo', 'United States of Ame')
# (1434, 'Paseo', 'Mexico')
# (1435, 'Velo', 'United States of Ame')
# (1436, 'Velo', 'Canada')
# (1437, 'Velo', 'France')
# (1438, 'VTT', 'France')
# (1439, 'VTT', 'United States of Ame')
# (1440, 'VTT', 'France')
# (1441, 'VTT', 'Mexico')
# (1442, 'Amarilla', 'Mexico')
# (1443, 'Amarilla', 'Mexico')
# (1444, 'Amarilla', 'Germany')
# (1445, 'Amarilla', 'United States of Ame')
# ...
# (53626, 'Battery Electric Veh', 'MODEL 3')
# (53627, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (53628, 'Battery Electric Veh', 'MODEL 3')
# (53629, 'Battery Electric Veh', 'MODEL Y')
# (53630, 'Battery Electric Veh', 'MODEL Y')
# (53631, 'Battery Electric Veh', 'MODEL Y')
# (53632, 'Battery Electric Veh', 'MODEL 3')
# (53633, 'Plug-in Hybrid Elect', 'WRANGLER')
# (53634, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53635, 'Battery Electric Veh', 'MODEL 3')
# (53636, 'Plug-in Hybrid Elect', 'PACIFICA')
# (53637, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53638, 'Battery Electric Veh', 'MODEL 3')
# (53639, 'Battery Electric Veh', 'MODEL Y')
# (53640, 'Battery Electric Veh', 'MODEL 3')
# (53641, 'Battery Electric Veh', 'MODEL 3')
# (53642, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53643, 'Plug-in Hybrid Elect', 'C-MAX')
# (53644, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53645, 'Battery Electric Veh', 'MODEL 3')
# (53646, 'Battery Electric Veh', 'MODEL Y')
# (53647, 'Battery Electric Veh', 'MODEL Y')
# (53648, 'Battery Electric Veh', 'MODEL 3')
# (53649, 'Battery Electric Veh', 'MODEL S')
# (53650, 'Plug-in Hybrid Elect', 'PACIFICA')
# (53651, 'Battery Electric Veh', 'MODEL 3')
# (53652, 'Battery Electric Veh', 'MODEL Y')
# (53653, 'Battery Electric Veh', 'ID.4')
# (53654, 'Battery Electric Veh', 'LEAF')
# (53655, 'Plug-in Hybrid Elect', 'XC60')
# (53656, 'Battery Electric Veh', 'MODEL Y')
# (53657, 'Plug-in Hybrid Elect', 'VOLT')
# (53658, 'Battery Electric Veh', 'LEAF')
# (53659, 'Battery Electric Veh', 'MODEL 3')
# (53660, 'Battery Electric Veh', 'MODEL Y')
# (53661, 'Battery Electric Veh', 'MODEL 3')
# (53662, 'Battery Electric Veh', 'E-GOLF')
# (53663, 'Battery Electric Veh', 'MODEL S')
# (53664, 'Plug-in Hybrid Elect', 'VOLT')
# (53665, 'Plug-in Hybrid Elect', 'PRIUS PLUG-IN')
# (53666, 'Battery Electric Veh', 'BOLT EV')
# (53667, 'Battery Electric Veh', 'MODEL Y')
# (53668, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (53669, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (53670, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53671, 'Battery Electric Veh', 'SOUL')
# (53672, 'Plug-in Hybrid Elect', 'S60')
# (53673, 'Plug-in Hybrid Elect', 'SPORTAGE')
# (53674, 'Battery Electric Veh', 'MODEL 3')
# (53675, 'Battery Electric Veh', 'IONIQ 5')
# (53676, 'Battery Electric Veh', 'EV6')
# (53677, 'Plug-in Hybrid Elect', 'CAYENNE')
# (53678, 'Battery Electric Veh', 'AIR')
# (53679, 'Battery Electric Veh', 'MODEL 3')
# (53680, 'Plug-in Hybrid Elect', 'NIRO')
# (53681, 'Battery Electric Veh', 'BOLT EUV')
# (53682, 'Plug-in Hybrid Elect', 'NIRO')
# (53683, 'Battery Electric Veh', 'LEAF')
# (53684, 'Battery Electric Veh', 'MODEL Y')
# (53685, 'Battery Electric Veh', 'E-TRON')
# (53686, 'Battery Electric Veh', 'MODEL 3')
# (53687, 'Battery Electric Veh', 'MODEL Y')
# (53688, 'Plug-in Hybrid Elect', 'VOLT')
# (53689, 'Battery Electric Veh', 'NIRO')
# (53690, 'Battery Electric Veh', 'MODEL Y')
# (53691, 'Battery Electric Veh', 'BOLT EV')
# (53692, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (53693, 'Battery Electric Veh', 'MODEL Y')
# (53694, 'Battery Electric Veh', 'LYRIQ')
# (53695, 'Plug-in Hybrid Elect', 'OUTLANDER')
# (53696, 'Battery Electric Veh', 'KONA ELECTRIC')
# (53697, 'Battery Electric Veh', 'MODEL 3')
# (53698, 'Battery Electric Veh', 'MODEL X')
# (53699, 'Plug-in Hybrid Elect', 'FUSION')
# (53700, 'Battery Electric Veh', 'MODEL X')
# (53701, 'Battery Electric Veh', 'EV6')
# (53702, 'Battery Electric Veh', 'MODEL Y')
# (53703, 'Plug-in Hybrid Elect', '530E')
# (53704, 'Battery Electric Veh', 'MODEL Y')
# (53705, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53706, 'Battery Electric Veh', 'MODEL X')
# (53707, 'Plug-in Hybrid Elect', 'XC60')
# (53708, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53709, 'Battery Electric Veh', 'MODEL Y')
# (53710, 'Plug-in Hybrid Elect', 'COUNTRYMAN')
# (53711, 'Battery Electric Veh', 'LEAF')
# (53712, 'Battery Electric Veh', 'MODEL 3')
# (53713, 'Plug-in Hybrid Elect', 'VOLT')
# (53714, 'Battery Electric Veh', '500')
# (53715, 'Battery Electric Veh', 'MODEL S')
# (53716, 'Plug-in Hybrid Elect', 'NIRO')
# (53717, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (53718, 'Battery Electric Veh', 'MODEL S')
# (53719, 'Plug-in Hybrid Elect', 'XC90')
# (53720, 'Battery Electric Veh', 'MODEL X')
# (53721, 'Plug-in Hybrid Elect', 'VOLT')
# (53722, 'Battery Electric Veh', 'MODEL 3')
# (53723, 'Battery Electric Veh', 'LEAF')
# (53724, 'Battery Electric Veh', 'MODEL Y')
# (53725, 'Plug-in Hybrid Elect', 'WRANGLER')
# (53726, 'Battery Electric Veh', 'MODEL 3')
# (53727, 'Battery Electric Veh', 'MODEL 3')
# (53728, 'Battery Electric Veh', 'SOUL')
# (53729, 'Battery Electric Veh', 'IX')
# (53730, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53731, 'Battery Electric Veh', 'FORTWO')
# (53732, 'Plug-in Hybrid Elect', '330E')
# (53733, 'Plug-in Hybrid Elect', 'XC90')
# (53734, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53735, 'Battery Electric Veh', 'RS E-TRON GT')
# (53736, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53737, 'Battery Electric Veh', 'LEAF')
# (53738, 'Battery Electric Veh', 'MODEL X')
# (53739, 'Battery Electric Veh', '500')
# (53740, 'Battery Electric Veh', 'MODEL 3')
# (53741, 'Battery Electric Veh', 'MODEL Y')
# (53742, 'Plug-in Hybrid Elect', 'XC60')
# (53743, 'Battery Electric Veh', 'MODEL 3')
# (53744, 'Battery Electric Veh', 'LEAF')
# (53745, 'Battery Electric Veh', 'E-TRON')
# (53746, 'Battery Electric Veh', 'MODEL Y')
# (53747, 'Battery Electric Veh', 'MODEL X')
# (53748, 'Battery Electric Veh', 'LEAF')
# (53749, 'Battery Electric Veh', 'MODEL S')
# (53750, 'Battery Electric Veh', 'LEAF')
# (53751, 'Battery Electric Veh', 'E-TRON')
# (53752, 'Battery Electric Veh', 'LEAF')
# (53753, 'Plug-in Hybrid Elect', 'XC90')
# (53754, 'Plug-in Hybrid Elect', 'XC60')
# (53755, 'Battery Electric Veh', 'R1S')
# (53756, 'Battery Electric Veh', 'MODEL 3')
# (53757, 'Battery Electric Veh', 'MODEL 3')
# (53758, 'Battery Electric Veh', 'MODEL 3')
# (53759, 'Battery Electric Veh', 'MODEL 3')
# (53760, 'Battery Electric Veh', 'MODEL Y')
# (53761, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53762, 'Battery Electric Veh', 'HARDTOP')
# (53763, 'Plug-in Hybrid Elect', 'C-MAX')
# (53764, 'Battery Electric Veh', 'E-GOLF')
# (53765, 'Battery Electric Veh', 'LEAF')
# (53766, 'Battery Electric Veh', 'HARDTOP')
# (53767, 'Battery Electric Veh', 'BOLT EV')
# (53768, 'Battery Electric Veh', 'LEAF')
# (53769, 'Battery Electric Veh', 'ROADSTER')
# (53770, 'Battery Electric Veh', 'LEAF')
# (53771, 'Battery Electric Veh', 'MODEL 3')
# (53772, 'Plug-in Hybrid Elect', 'XC60')
# (53773, 'Battery Electric Veh', 'LEAF')
# (53774, 'Plug-in Hybrid Elect', 'PACIFICA')
# (53775, 'Plug-in Hybrid Elect', 'FUSION')
# (53776, 'Battery Electric Veh', 'LEAF')
# (53777, 'Plug-in Hybrid Elect', 'PRIUS PLUG-IN')
# (53778, 'Battery Electric Veh', 'LEAF')
# (53779, 'Battery Electric Veh', 'MODEL S')
# (53780, 'Plug-in Hybrid Elect', 'RAV4 PRIME')
# (53781, 'Plug-in Hybrid Elect', 'PACIFICA')
# (53782, 'Plug-in Hybrid Elect', 'PACIFICA')
# (53783, 'Battery Electric Veh', 'MODEL X')
# (53784, 'Battery Electric Veh', 'NIRO')
# (53785, 'Battery Electric Veh', 'LEAF')
# (53786, 'Battery Electric Veh', 'MODEL Y')
# (53787, 'Battery Electric Veh', 'LEAF')
# (53788, 'Battery Electric Veh', 'FOCUS')
# (53789, 'Plug-in Hybrid Elect', 'PACIFICA')
# (53790, 'Plug-in Hybrid Elect', 'CLARITY')
# (53791, 'Battery Electric Veh', 'LEAF')
# (53792, 'Plug-in Hybrid Elect', 'VOLT')
# (53793, 'Plug-in Hybrid Elect', 'WRANGLER')
# (53794, 'Battery Electric Veh', 'MODEL S')
# (53795, 'Battery Electric Veh', 'MODEL 3')
# (53796, 'Battery Electric Veh', 'MODEL Y')
# (53797, 'Battery Electric Veh', 'ID.4')
# (53798, 'Battery Electric Veh', 'LEAF')
# (53799, 'Battery Electric Veh', 'LEAF')
# (53800, 'Battery Electric Veh', 'MODEL 3')
# (53801, 'Battery Electric Veh', 'ROADSTER')
# (53802, 'Battery Electric Veh', 'E-GOLF')
# (53803, 'Battery Electric Veh', 'MODEL Y')
# (53804, 'Battery Electric Veh', 'MODEL Y')
# (53805, 'Plug-in Hybrid Elect', 'PACIFICA')
# (53806, 'Battery Electric Veh', 'TAYCAN')
# (53807, 'Battery Electric Veh', 'MODEL Y')
# (53808, 'Plug-in Hybrid Elect', 'PACIFICA')
# (53809, 'Plug-in Hybrid Elect', 'SORENTO')
# (53810, 'Battery Electric Veh', 'PS2')
# (53811, 'Plug-in Hybrid Elect', 'VOLT')
# (53812, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53813, 'Battery Electric Veh', 'LEAF')
# (53814, 'Battery Electric Veh', 'BOLT EV')
# (53815, 'Battery Electric Veh', 'MODEL 3')
# (53816, 'Plug-in Hybrid Elect', 'Q5 E')
# (53817, 'Battery Electric Veh', 'MODEL 3')
# (53818, 'Battery Electric Veh', 'MODEL S')
# (53819, 'Battery Electric Veh', 'MODEL X')
# (53820, 'Battery Electric Veh', 'LEAF')
# (53821, 'Battery Electric Veh', 'MODEL 3')
# (53822, 'Battery Electric Veh', 'IONIQ 5')
# (53823, 'Plug-in Hybrid Elect', 'X3')
# (53824, 'Battery Electric Veh', 'MODEL 3')
# (53825, 'Battery Electric Veh', 'R1T')
# (53826, 'Battery Electric Veh', 'MODEL 3')
# (53827, 'Plug-in Hybrid Elect', 'PACIFICA')
# (53828, 'Plug-in Hybrid Elect', 'A3')
# (53829, 'Battery Electric Veh', 'XC40')
# (53830, 'Battery Electric Veh', 'MODEL Y')
# (53831, 'Plug-in Hybrid Elect', 'C-MAX')
# (53832, 'Battery Electric Veh', 'MODEL 3')
# (53833, 'Battery Electric Veh', 'HARDTOP')
# (53834, 'Plug-in Hybrid Elect', 'Q5')
# (53835, 'Battery Electric Veh', 'MODEL X')
# (53836, 'Battery Electric Veh', 'LEAF')
# (53837, 'Battery Electric Veh', 'MODEL X')
# (53838, 'Battery Electric Veh', 'MODEL S')
# (53839, 'Battery Electric Veh', 'I-PACE')
# (53840, 'Battery Electric Veh', 'LEAF')
# (53841, 'Battery Electric Veh', 'MODEL Y')
# (53842, 'Battery Electric Veh', 'MODEL Y')
# (53843, 'Battery Electric Veh', 'ID.4')
# (53844, 'Battery Electric Veh', 'MODEL Y')
# (53845, 'Battery Electric Veh', 'MODEL Y')
# (53846, 'Battery Electric Veh', 'MODEL 3')
# (53847, 'Plug-in Hybrid Elect', 'A3')
# (53848, 'Battery Electric Veh', 'LEAF')
# (53849, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53850, 'Battery Electric Veh', 'I-PACE')
# (53851, 'Plug-in Hybrid Elect', 'PRIUS PLUG-IN')
# (53852, 'Battery Electric Veh', 'LEAF')
# (53853, 'Plug-in Hybrid Elect', 'NIRO')
# (53854, 'Battery Electric Veh', 'MODEL Y')
# (53855, 'Plug-in Hybrid Elect', 'X3')
# (53856, 'Battery Electric Veh', 'LEAF')
# (53857, 'Battery Electric Veh', 'MODEL X')
# (53858, 'Battery Electric Veh', 'MODEL 3')
# (53859, 'Battery Electric Veh', 'HARDTOP')
# (53860, 'Battery Electric Veh', 'MODEL 3')
# (53861, 'Battery Electric Veh', 'MODEL 3')
# (53862, 'Battery Electric Veh', 'MODEL X')
# (53863, 'Battery Electric Veh', 'LEAF')
# (53864, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53865, 'Battery Electric Veh', 'ID.4')
# (53866, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53867, 'Plug-in Hybrid Elect', 'ESCAPE')
# (53868, 'Battery Electric Veh', 'MODEL 3')
# (53869, 'Battery Electric Veh', 'MODEL Y')
# (53870, 'Battery Electric Veh', 'MODEL Y')
# (53871, 'Battery Electric Veh', 'MODEL 3')
# (53872, 'Battery Electric Veh', 'BOLT EV')
# (53873, 'Plug-in Hybrid Elect', 'XC60')
# (53874, 'Battery Electric Veh', 'MODEL 3')
# (53875, 'Battery Electric Veh', 'MODEL Y')
# (53876, 'Battery Electric Veh', 'MODEL Y')
# (53877, 'Battery Electric Veh', 'MODEL S')
# (53878, 'Battery Electric Veh', '')
# (53879, 'Battery Electric Veh', 'MODEL S')
# (53880, 'Battery Electric Veh', 'MODEL Y')
# (53881, 'Battery Electric Veh', 'MODEL Y')
# (53882, 'Battery Electric Veh', 'MODEL 3')
# (53883, 'Battery Electric Veh', 'MODEL 3')
# (53884, 'Battery Electric Veh', 'ID.4')
# (53885, 'Battery Electric Veh', 'LEAF')
# (53886, 'Battery Electric Veh', 'E-GOLF')
# (53887, 'Plug-in Hybrid Elect', 'VOLT')
# (53888, 'Battery Electric Veh', 'NIRO')
# (53889, 'Battery Electric Veh', 'MODEL Y')
# (53890, 'Battery Electric Veh', 'MODEL 3')
# (53891, 'Battery Electric Veh', 'EQS-CLASS SUV')
# (53892, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53893, 'Battery Electric Veh', 'LEAF')
# (53894, 'Battery Electric Veh', 'MODEL 3')
# (53895, 'Battery Electric Veh', 'R1T')
# (53896, 'Battery Electric Veh', 'MODEL 3')
# (53897, 'Plug-in Hybrid Elect', 'I3')
# (53898, 'Battery Electric Veh', 'MODEL Y')
# (53899, 'Battery Electric Veh', 'MODEL 3')
# (53900, 'Battery Electric Veh', 'MODEL S')
# (53901, 'Battery Electric Veh', 'MODEL 3')
# (53902, 'Battery Electric Veh', 'MODEL S')
# (53903, 'Battery Electric Veh', 'MODEL 3')
# (53904, 'Plug-in Hybrid Elect', 'XC60')
# (53905, 'Battery Electric Veh', 'MODEL 3')
# (53906, 'Battery Electric Veh', 'E-TRON')
# (53907, 'Battery Electric Veh', 'MODEL 3')
# (53908, 'Plug-in Hybrid Elect', 'FUSION')
# (53909, 'Battery Electric Veh', 'MODEL 3')
# (53910, 'Battery Electric Veh', 'MODEL 3')
# (53911, 'Battery Electric Veh', 'MODEL 3')
# (53912, 'Battery Electric Veh', 'LEAF')
# (53913, 'Battery Electric Veh', 'MODEL Y')
# (53914, 'Battery Electric Veh', 'MODEL 3')
# (53915, 'Battery Electric Veh', 'MODEL 3')
# (53916, 'Battery Electric Veh', 'MODEL S')
# (53917, 'Battery Electric Veh', 'MODEL S')
# (53918, 'Battery Electric Veh', 'EQS-CLASS SUV')
# (53919, 'Battery Electric Veh', 'MODEL 3')
# (53920, 'Battery Electric Veh', 'MODEL 3')
# (53921, 'Battery Electric Veh', 'EV6')
# (53922, 'Battery Electric Veh', 'MODEL 3')
# (53923, 'Battery Electric Veh', 'MODEL Y')
# (53924, 'Battery Electric Veh', 'E-TRON')
# (53925, 'Battery Electric Veh', 'BOLT EV')
# (53926, 'Battery Electric Veh', 'BOLT EV')
# (53927, 'Battery Electric Veh', 'MODEL 3')
# (53928, 'Plug-in Hybrid Elect', 'I3')
# (53929, 'Battery Electric Veh', 'LEAF')
# (53930, 'Battery Electric Veh', 'EV6')
# (53931, 'Battery Electric Veh', 'IONIQ 5')
# (53932, 'Battery Electric Veh', 'MODEL 3')
# (53933, 'Battery Electric Veh', 'MODEL 3')
# (53934, 'Battery Electric Veh', 'MODEL X')
# (53935, 'Battery Electric Veh', 'MODEL Y')
# (53936, 'Battery Electric Veh', 'MODEL 3')
# (53937, 'Battery Electric Veh', 'MODEL 3')
# (53938, 'Battery Electric Veh', 'MODEL S')
# (53939, 'Battery Electric Veh', 'MODEL S')
# (53940, 'Battery Electric Veh', 'MODEL 3')
# (53941, 'Plug-in Hybrid Elect', 'I3')
# (53942, 'Plug-in Hybrid Elect', 'NIRO')
# (53943, 'Battery Electric Veh', 'EV6')
# (53944, 'Battery Electric Veh', 'BOLT EV')
# (53945, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53946, 'Battery Electric Veh', 'MODEL Y')
# (53947, 'Battery Electric Veh', 'XC40')
# (53948, 'Battery Electric Veh', 'E-GOLF')
# (53949, 'Battery Electric Veh', 'MODEL Y')
# (53950, 'Battery Electric Veh', 'MODEL 3')
# (53951, 'Plug-in Hybrid Elect', 'FUSION')
# (53952, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53953, 'Plug-in Hybrid Elect', 'CAYENNE')
# (53954, 'Battery Electric Veh', 'MODEL X')
# (53955, 'Battery Electric Veh', 'MODEL 3')
# (53956, 'Battery Electric Veh', 'MODEL S')
# (53957, 'Battery Electric Veh', 'MODEL S')
# (53958, 'Battery Electric Veh', 'LEAF')
# (53959, 'Battery Electric Veh', 'E-TRON')
# (53960, 'Battery Electric Veh', 'MODEL Y')
# (53961, 'Battery Electric Veh', 'MODEL X')
# (53962, 'Battery Electric Veh', 'MODEL 3')
# (53963, 'Battery Electric Veh', 'MODEL S')
# (53964, 'Battery Electric Veh', 'MODEL Y')
# (53965, 'Battery Electric Veh', 'MODEL Y')
# (53966, 'Plug-in Hybrid Elect', 'C-MAX')
# (53967, 'Battery Electric Veh', 'MODEL 3')
# (53968, 'Battery Electric Veh', 'MODEL X')
# (53969, 'Battery Electric Veh', 'MODEL 3')
# (53970, 'Battery Electric Veh', 'LEAF')
# (53971, 'Plug-in Hybrid Elect', 'C-MAX')
# (53972, 'Battery Electric Veh', 'MODEL 3')
# (53973, 'Battery Electric Veh', 'MUSTANG MACH-E')
# (53974, 'Plug-in Hybrid Elect', 'I3')
# (53975, 'Battery Electric Veh', 'MODEL 3')
# (53976, 'Battery Electric Veh', 'MODEL S')
# (53977, 'Battery Electric Veh', 'MODEL Y')
# (53978, 'Plug-in Hybrid Elect', 'PRIUS PRIME')
# (53979, 'Plug-in Hybrid Elect', 'FUSION')
# (53980, 'Battery Electric Veh', 'MODEL Y')
# (53981, 'Battery Electric Veh', 'MODEL Y')
# (53982, 'Battery Electric Veh', 'MODEL Y')
# (53983, 'Battery Electric Veh', 'MODEL Y')
# (53984, 'Battery Electric Veh', 'LEAF')
# (53985, 'Plug-in Hybrid Elect', 'I3')
# (53986, 'Battery Electric Veh', 'MODEL S')
# (53987, 'Plug-in Hybrid Elect', 'CLARITY')
# (53988, 'Plug-in Hybrid Elect', 'VOLT')
# (53989, 'Battery Electric Veh', 'MODEL Y')
# (53990, 'Battery Electric Veh', 'I3')
# (53991, 'Battery Electric Veh', 'LEAF')
# (53992, 'Plug-in Hybrid Elect', 'FUSION')
# (53993, 'Battery Electric Veh', 'I3')
# (53994, 'Battery Electric Veh', 'MODEL 3')
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
rows
# Out:
# [(1, 'Battery Electric Veh', 'MODEL X'),
#  (2, 'Plug-in Hybrid Elect', 'CLARITY'),
#  (3, 'Battery Electric Veh', 'MODEL 3'),
#  (4, 'Battery Electric Veh', 'LEAF'),
#  (5, 'Battery Electric Veh', 'MODEL S'),
#  (6, 'Plug-in Hybrid Elect', 'CLARITY'),
#  (7, 'Plug-in Hybrid Elect', 'FUSION'),
#  (8, 'Plug-in Hybrid Elect', 'Q5 E'),
#  (9, 'Plug-in Hybrid Elect', 'C-MAX'),
#  (10, 'Battery Electric Veh', 'MODEL S'),
#  (11, 'Battery Electric Veh', 'LEAF'),
#  (12, 'Battery Electric Veh', 'MODEL Y'),
#  (13, 'Battery Electric Veh', 'MODEL 3'),
#  (14, 'Battery Electric Veh', 'MODEL 3'),
#  (15, 'Plug-in Hybrid Elect', 'C-MAX'),
#  (16, 'Plug-in Hybrid Elect', 'NIRO'),
#  (17, 'Battery Electric Veh', 'LEAF'),
#  (18, 'Battery Electric Veh', 'MODEL S'),
#  (19, 'Plug-in Hybrid Elect', 'VOLT'),
#  (20, 'Battery Electric Veh', 'BOLT EV'),
#  (21, 'Battery Electric Veh', 'MODEL 3'),
#  (22, 'Battery Electric Veh', 'MODEL S'),
#  (23, 'Plug-in Hybrid Elect', 'VOLT'),
#  (24, 'Battery Electric Veh', 'LEAF'),
#  (25, 'Battery Electric Veh', 'MODEL S'),
#  (26, 'Battery Electric Veh', 'FORTWO'),
#  (27, 'Battery Electric Veh', 'LEAF'),
#  (28, 'Battery Electric Veh', 'LEAF'),
#  (29, 'Battery Electric Veh', 'MODEL 3'),
#  (30, 'Plug-in Hybrid Elect', 'X5'),
#  (31, 'Battery Electric Veh', 'MODEL Y'),
#  (32, 'Battery Electric Veh', 'MODEL 3'),
#  (33, 'Battery Electric Veh', 'MODEL 3'),
#  (34, 'Battery Electric Veh', 'LEAF'),
#  (35, 'Battery Electric Veh', 'LEAF'),
#  (36, 'Battery Electric Veh', 'MODEL 3'),
#  (37, 'Plug-in Hybrid Elect', 'SORENTO'),
#  (38, 'Battery Electric Veh', 'BOLT EV'),
#  (39, 'Battery Electric Veh', 'MODEL 3'),
#  (40, 'Battery Electric Veh', 'MODEL 3'),
#  (41, 'Plug-in Hybrid Elect', 'PRIUS PRIME'),
#  (42, 'Plug-in Hybrid Elect', 'I3'),
#  (43, 'Battery Electric Veh', 'LEAF'),
#  (44, 'Battery Electric Veh', 'MODEL S'),
#  (45, 'Battery Electric Veh', 'LEAF'),
#  (46, 'Battery Electric Veh', 'MODEL X'),
#  (47, 'Battery Electric Veh', 'LEAF'),
#  (48, 'Battery Electric Veh', 'BOLT EV'),
#  (49, 'Battery Electric Veh', 'MODEL 3'),
#  (50, 'Battery Electric Veh', 'MODEL 3'),
#  (51, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (52, 'Battery Electric Veh', 'SPARK'),
#  (53, 'Battery Electric Veh', 'MODEL S'),
#  (54, 'Battery Electric Veh', 'MODEL S'),
#  (55, 'Battery Electric Veh', 'LEAF'),
#  (56, 'Battery Electric Veh', 'MODEL Y'),
#  (57, 'Battery Electric Veh', 'LEAF'),
#  (58, 'Battery Electric Veh', 'LEAF'),
#  (59, 'Plug-in Hybrid Elect', 'X5'),
#  (60, 'Battery Electric Veh', 'MODEL 3'),
#  (61, 'Battery Electric Veh', 'BOLT EV'),
#  (62, 'Battery Electric Veh', 'MODEL 3'),
#  (63, 'Battery Electric Veh', '500'),
#  (64, 'Battery Electric Veh', 'MODEL S'),
#  (65, 'Plug-in Hybrid Elect', 'C-MAX'),
#  (66, 'Battery Electric Veh', 'MODEL S'),
#  (67, 'Battery Electric Veh', 'MODEL X'),
#  (68, 'Battery Electric Veh', 'MODEL 3'),
#  (69, 'Plug-in Hybrid Elect', 'VOLT'),
#  (70, 'Plug-in Hybrid Elect', 'PRIUS PRIME'),
#  (71, 'Plug-in Hybrid Elect', 'XC60'),
#  (72, 'Battery Electric Veh', 'MODEL 3'),
#  (73, 'Plug-in Hybrid Elect', 'VOLT'),
#  (74, 'Battery Electric Veh', 'LEAF'),
#  (75, 'Plug-in Hybrid Elect', 'VOLT'),
#  (76, 'Plug-in Hybrid Elect', 'VOLT'),
#  (77, 'Plug-in Hybrid Elect', 'XC90'),
#  (78, 'Battery Electric Veh', 'MODEL 3'),
#  (79, 'Battery Electric Veh', 'MODEL 3'),
#  (80, 'Battery Electric Veh', 'NIRO'),
#  (81, 'Battery Electric Veh', 'MODEL X'),
#  (82, 'Battery Electric Veh', 'MODEL 3'),
#  (83, 'Battery Electric Veh', 'NIRO'),
#  (84, 'Battery Electric Veh', 'MODEL 3'),
#  (85, 'Battery Electric Veh', 'BOLT EV'),
#  (86, 'Battery Electric Veh', 'MODEL 3'),
#  (87, 'Battery Electric Veh', 'SPARK'),
#  (88, 'Battery Electric Veh', 'FOCUS'),
#  (89, 'Plug-in Hybrid Elect', 'FUSION'),
#  (90, 'Battery Electric Veh', 'SOUL EV'),
#  (91, 'Battery Electric Veh', 'MODEL S'),
#  (92, 'Battery Electric Veh', 'MODEL X'),
#  (93, 'Battery Electric Veh', 'LEAF'),
#  (94, 'Plug-in Hybrid Elect', 'XC60'),
#  (95, 'Battery Electric Veh', 'LEAF'),
#  (96, 'Battery Electric Veh', 'LEAF'),
#  (97, 'Battery Electric Veh', 'MODEL 3'),
#  (98, 'Battery Electric Veh', 'NIRO'),
#  (99, 'Plug-in Hybrid Elect', 'FUSION'),
#  (100, 'Battery Electric Veh', 'MODEL Y'),
#  (101, 'Plug-in Hybrid Elect', 'A3'),
#  (102, 'Plug-in Hybrid Elect', 'VOLT'),
#  (103, 'Battery Electric Veh', 'LEAF'),
#  (104, 'Battery Electric Veh', 'MODEL 3'),
#  (105, 'Plug-in Hybrid Elect', 'X5'),
#  (106, 'Battery Electric Veh', 'MODEL 3'),
#  (107, 'Battery Electric Veh', 'LEAF'),
#  (108, 'Battery Electric Veh', 'MODEL 3'),
#  (109, 'Battery Electric Veh', 'MODEL S'),
#  (110, 'Plug-in Hybrid Elect', 'FUSION'),
#  (111, 'Plug-in Hybrid Elect', 'NIRO'),
#  (112, 'Battery Electric Veh', 'MODEL Y'),
#  (113, 'Battery Electric Veh', 'LEAF'),
#  (114, 'Battery Electric Veh', 'LEAF'),
#  (115, 'Battery Electric Veh', 'MODEL Y'),
#  (116, 'Plug-in Hybrid Elect', 'C-MAX'),
#  (117, 'Battery Electric Veh', 'MODEL X'),
#  (118, 'Battery Electric Veh', 'MODEL S'),
#  (119, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (120, 'Plug-in Hybrid Elect', 'PACIFICA'),
#  (121, 'Battery Electric Veh', 'LEAF'),
#  (122, 'Battery Electric Veh', 'LEAF'),
#  (123, 'Plug-in Hybrid Elect', 'C-MAX'),
#  (124, 'Plug-in Hybrid Elect', 'VOLT'),
#  (125, 'Plug-in Hybrid Elect', 'OPTIMA'),
#  (126, 'Battery Electric Veh', 'MODEL 3'),
#  (127, 'Plug-in Hybrid Elect', 'PACIFICA'),
#  (128, 'Battery Electric Veh', 'MODEL Y'),
#  (129, 'Plug-in Hybrid Elect', 'VOLT'),
#  (130, 'Battery Electric Veh', 'MODEL Y'),
#  (131, 'Battery Electric Veh', 'MODEL S'),
#  (132, 'Plug-in Hybrid Elect', 'NX'),
#  (133, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (134, 'Battery Electric Veh', 'BOLT EV'),
#  (135, 'Battery Electric Veh', 'MODEL 3'),
#  (136, 'Battery Electric Veh', 'MODEL 3'),
#  (137, 'Battery Electric Veh', 'LEAF'),
#  (138, 'Plug-in Hybrid Elect', 'PACIFICA'),
#  (139, 'Battery Electric Veh', 'MODEL S'),
#  (140, 'Plug-in Hybrid Elect', 'OPTIMA'),
#  (141, 'Battery Electric Veh', 'MODEL Y'),
#  (142, 'Battery Electric Veh', 'MODEL 3'),
#  (143, 'Battery Electric Veh', 'MODEL 3'),
#  (144, 'Plug-in Hybrid Elect', 'PRIUS PRIME'),
#  (145, 'Plug-in Hybrid Elect', 'PRIUS PLUG-IN'),
#  (146, 'Battery Electric Veh', 'MODEL Y'),
#  (147, 'Battery Electric Veh', 'MUSTANG MACH-E'),
#  (148, 'Battery Electric Veh', 'MODEL Y'),
#  (149, 'Battery Electric Veh', 'BOLT EUV'),
#  (150, 'Battery Electric Veh', 'MODEL Y'),
#  (151, 'Battery Electric Veh', 'MODEL Y'),
#  (152, 'Plug-in Hybrid Elect', 'CAYENNE'),
#  (153, 'Battery Electric Veh', 'BOLT EV'),
#  (154, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (155, 'Plug-in Hybrid Elect', 'ELR'),
#  (156, 'Plug-in Hybrid Elect', 'X3'),
#  (157, 'Battery Electric Veh', 'KONA ELECTRIC'),
#  (158, 'Battery Electric Veh', 'MODEL Y'),
#  (159, 'Battery Electric Veh', 'MODEL X'),
#  (160, 'Battery Electric Veh', 'MODEL Y'),
#  (161, 'Plug-in Hybrid Elect', 'VOLT'),
#  (162, 'Plug-in Hybrid Elect', '530E'),
#  (163, 'Battery Electric Veh', 'MODEL S'),
#  (164, 'Battery Electric Veh', 'EQB-CLASS'),
#  (165, 'Battery Electric Veh', 'MODEL Y'),
#  (166, 'Battery Electric Veh', 'MODEL X'),
#  (167, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (168, 'Battery Electric Veh', 'MODEL 3'),
#  (169, 'Battery Electric Veh', 'MODEL Y'),
#  (170, 'Battery Electric Veh', 'MODEL 3'),
#  (171, 'Battery Electric Veh', 'MODEL 3'),
#  (172, 'Battery Electric Veh', 'LEAF'),
#  (173, 'Battery Electric Veh', 'MODEL Y'),
#  (174, 'Plug-in Hybrid Elect', 'NIRO'),
#  (175, 'Battery Electric Veh', 'MODEL Y'),
#  (176, 'Battery Electric Veh', 'LEAF'),
#  (177, 'Battery Electric Veh', 'MODEL 3'),
#  (178, 'Battery Electric Veh', 'MODEL Y'),
#  (179, 'Battery Electric Veh', 'MODEL S'),
#  (180, 'Plug-in Hybrid Elect', 'PRIUS PRIME'),
#  (181, 'Battery Electric Veh', 'LEAF'),
#  (182, 'Battery Electric Veh', 'R1T'),
#  (183, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (184, 'Battery Electric Veh', 'MODEL 3'),
#  (185, 'Battery Electric Veh', 'FORTWO'),
#  (186, 'Battery Electric Veh', 'MODEL 3'),
#  (187, 'Battery Electric Veh', 'TRANSIT'),
#  (188, 'Battery Electric Veh', 'MODEL Y'),
#  (189, 'Plug-in Hybrid Elect', 'VOLT'),
#  (190, 'Battery Electric Veh', 'MODEL Y'),
#  (191, 'Battery Electric Veh', 'E-GOLF'),
#  (192, 'Battery Electric Veh', 'MODEL S'),
#  (193, 'Battery Electric Veh', 'MODEL Y'),
#  (194, 'Battery Electric Veh', 'MODEL Y'),
#  (195, 'Battery Electric Veh', 'MODEL 3'),
#  (196, 'Battery Electric Veh', 'MODEL Y'),
#  (197, 'Battery Electric Veh', 'MODEL Y'),
#  (198, 'Battery Electric Veh', 'BOLT EV'),
#  (199, 'Battery Electric Veh', 'MODEL S'),
#  (200, 'Battery Electric Veh', 'MODEL Y'),
#  (201, 'Battery Electric Veh', 'ID.4'),
#  (202, 'Battery Electric Veh', 'MODEL X'),
#  (203, 'Battery Electric Veh', 'LEAF'),
#  (204, 'Battery Electric Veh', 'MODEL S'),
#  (205, 'Battery Electric Veh', 'BOLT EV'),
#  (206, 'Battery Electric Veh', 'LEAF'),
#  (207, 'Battery Electric Veh', 'LEAF'),
#  (208, 'Battery Electric Veh', 'LEAF'),
#  (209, 'Battery Electric Veh', 'MODEL 3'),
#  (210, 'Battery Electric Veh', 'MODEL 3'),
#  (211, 'Battery Electric Veh', 'LEAF'),
#  (212, 'Battery Electric Veh', 'MODEL Y'),
#  (213, 'Battery Electric Veh', 'MODEL X'),
#  (214, 'Battery Electric Veh', 'MODEL Y'),
#  (215, 'Battery Electric Veh', 'BOLT EV'),
#  (216, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (217, 'Battery Electric Veh', 'LEAF'),
#  (218, 'Battery Electric Veh', 'MODEL 3'),
#  (219, 'Battery Electric Veh', 'MODEL Y'),
#  (220, 'Battery Electric Veh', 'MODEL Y'),
#  (221, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (222, 'Battery Electric Veh', 'LEAF'),
#  (223, 'Battery Electric Veh', 'MODEL 3'),
#  (224, 'Battery Electric Veh', 'FORTWO ELECTRIC DRIV'),
#  (225, 'Battery Electric Veh', 'MODEL 3'),
#  (226, 'Battery Electric Veh', 'MODEL 3'),
#  (227, 'Battery Electric Veh', 'MODEL 3'),
#  (228, 'Battery Electric Veh', 'NIRO'),
#  (229, 'Battery Electric Veh', 'MODEL Y'),
#  (230, 'Battery Electric Veh', 'E-GOLF'),
#  (231, 'Battery Electric Veh', 'LEAF'),
#  (232, 'Battery Electric Veh', 'MODEL 3'),
#  (233, 'Plug-in Hybrid Elect', 'NIRO'),
#  (234, 'Plug-in Hybrid Elect', 'C-MAX'),
#  (235, 'Battery Electric Veh', 'MODEL 3'),
#  (236, 'Battery Electric Veh', 'BOLT EV'),
#  (237, 'Battery Electric Veh', 'MODEL S'),
#  (238, 'Battery Electric Veh', 'MODEL Y'),
#  (239, 'Battery Electric Veh', 'MODEL 3'),
#  (240, 'Battery Electric Veh', 'MODEL Y'),
#  (241, 'Battery Electric Veh', 'I-PACE'),
#  (242, 'Battery Electric Veh', 'SOUL EV'),
#  (243, 'Battery Electric Veh', 'MODEL 3'),
#  (244, 'Battery Electric Veh', 'ID.4'),
#  (245, 'Battery Electric Veh', 'LEAF'),
#  (246, 'Battery Electric Veh', 'MODEL 3'),
#  (247, 'Battery Electric Veh', 'MODEL 3'),
#  (248, 'Plug-in Hybrid Elect', 'AVIATOR'),
#  (249, 'Battery Electric Veh', 'MODEL 3'),
#  (250, 'Battery Electric Veh', 'LEAF'),
#  (251, 'Battery Electric Veh', 'MODEL 3'),
#  (252, 'Battery Electric Veh', 'MODEL 3'),
#  (253, 'Battery Electric Veh', 'TAYCAN'),
#  (254, 'Battery Electric Veh', 'MODEL S'),
#  (255, 'Battery Electric Veh', 'E-TRON'),
#  (256, 'Battery Electric Veh', 'MODEL Y'),
#  (257, 'Battery Electric Veh', 'MODEL Y'),
#  (258, 'Battery Electric Veh', 'MODEL 3'),
#  (259, 'Plug-in Hybrid Elect', 'FUSION'),
#  (260, 'Battery Electric Veh', 'MODEL S'),
#  (261, 'Battery Electric Veh', 'MODEL 3'),
#  (262, 'Battery Electric Veh', 'MODEL X'),
#  (263, 'Battery Electric Veh', 'MODEL Y'),
#  (264, 'Battery Electric Veh', 'ID.4'),
#  (265, 'Plug-in Hybrid Elect', 'PACIFICA'),
#  (266, 'Plug-in Hybrid Elect', 'C-CLASS'),
#  (267, 'Plug-in Hybrid Elect', 'OUTLANDER'),
#  (268, 'Battery Electric Veh', 'I3'),
#  (269, 'Battery Electric Veh', 'MODEL Y'),
#  (270, 'Battery Electric Veh', 'SOUL'),
#  (271, 'Plug-in Hybrid Elect', 'SONATA'),
#  (272, 'Plug-in Hybrid Elect', 'VOLT'),
#  (273, 'Battery Electric Veh', 'MODEL S'),
#  (274, 'Battery Electric Veh', 'LEAF'),
#  (275, 'Battery Electric Veh', 'MODEL 3'),
#  (276, 'Plug-in Hybrid Elect', 'GRAND CHEROKEE'),
#  (277, 'Plug-in Hybrid Elect', 'VOLT'),
#  (278, 'Plug-in Hybrid Elect', '530E'),
#  (279, 'Battery Electric Veh', 'MODEL 3'),
#  (280, 'Battery Electric Veh', 'MODEL 3'),
#  (281, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (282, 'Battery Electric Veh', 'MODEL X'),
#  (283, 'Battery Electric Veh', 'LEAF'),
#  (284, 'Battery Electric Veh', 'MODEL S'),
#  (285, 'Battery Electric Veh', 'LEAF'),
#  (286, 'Battery Electric Veh', 'LEAF'),
#  (287, 'Plug-in Hybrid Elect', 'VOLT'),
#  (288, 'Plug-in Hybrid Elect', 'PRIUS PRIME'),
#  (289, 'Battery Electric Veh', 'MODEL 3'),
#  (290, 'Battery Electric Veh', 'TRANSIT'),
#  (291, 'Plug-in Hybrid Elect', 'PACIFICA'),
#  (292, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (293, 'Battery Electric Veh', 'MODEL X'),
#  (294, 'Plug-in Hybrid Elect', 'PRIUS PLUG-IN'),
#  (295, 'Battery Electric Veh', 'MODEL Y'),
#  (296, 'Battery Electric Veh', 'MODEL 3'),
#  (297, 'Battery Electric Veh', 'BOLT EV'),
#  (298, 'Plug-in Hybrid Elect', 'VOLT'),
#  (299, 'Battery Electric Veh', 'BOLT EV'),
#  (300, 'Battery Electric Veh', 'MODEL X'),
#  (301, 'Plug-in Hybrid Elect', 'VOLT'),
#  (302, 'Battery Electric Veh', 'MODEL Y'),
#  (303, 'Plug-in Hybrid Elect', 'RAV4 PRIME'),
#  (304, 'Battery Electric Veh', 'MODEL 3'),
#  (305, 'Battery Electric Veh', 'R1T'),
#  (306, 'Battery Electric Veh', 'MODEL 3'),
#  (307, 'Plug-in Hybrid Elect', 'SPORTAGE'),
#  (308, 'Battery Electric Veh', 'NIRO'),
#  (309, 'Plug-in Hybrid Elect', 'XC90'),
#  (310, 'Plug-in Hybrid Elect', 'I3'),
#  (311, 'Battery Electric Veh', 'MODEL 3'),
#  (312, 'Battery Electric Veh', 'MODEL X'),
#  (313, 'Battery Electric Veh', 'MODEL S'),
#  (314, 'Plug-in Hybrid Elect', 'OUTLANDER'),
#  (315, 'Battery Electric Veh', 'MODEL Y'),
#  (316, 'Battery Electric Veh', 'IONIQ 5'),
#  (317, 'Battery Electric Veh', 'MODEL Y'),
#  (318, 'Battery Electric Veh', 'MODEL Y'),
#  (319, 'Battery Electric Veh', 'MODEL Y'),
#  (320, 'Battery Electric Veh', 'MODEL 3'),
#  (321, 'Battery Electric Veh', 'MODEL Y'),
#  (322, 'Plug-in Hybrid Elect', 'XC90'),
#  (323, 'Battery Electric Veh', 'E-TRON'),
#  (324, 'Battery Electric Veh', 'LEAF'),
#  (325, 'Battery Electric Veh', 'LEAF'),
#  (326, 'Battery Electric Veh', 'MODEL 3'),
#  (327, 'Plug-in Hybrid Elect', 'A3'),
#  (328, 'Plug-in Hybrid Elect', 'X5'),
#  (329, 'Battery Electric Veh', 'MODEL Y'),
#  (330, 'Battery Electric Veh', '500'),
#  (331, 'Battery Electric Veh', 'LEAF'),
#  (332, 'Plug-in Hybrid Elect', 'I3'),
#  (333, 'Battery Electric Veh', 'BOLT EV'),
#  (334, 'Battery Electric Veh', 'BOLT EV'),
#  (335, 'Battery Electric Veh', 'FORTWO ELECTRIC DRIV'),
#  (336, 'Battery Electric Veh', 'MODEL Y'),
#  (337, 'Battery Electric Veh', 'MODEL 3'),
#  (338, 'Battery Electric Veh', 'MODEL Y'),
#  (339, 'Battery Electric Veh', 'MODEL 3'),
#  (340, 'Battery Electric Veh', 'MODEL S'),
#  (341, 'Battery Electric Veh', 'R1T'),
#  (342, 'Battery Electric Veh', 'MODEL 3'),
#  (343, 'Battery Electric Veh', 'MODEL 3'),
#  (344, 'Plug-in Hybrid Elect', 'I3'),
#  (345, 'Battery Electric Veh', 'MODEL 3'),
#  (346, 'Plug-in Hybrid Elect', 'X5'),
#  (347, 'Battery Electric Veh', 'MODEL 3'),
#  (348, 'Plug-in Hybrid Elect', 'NX'),
#  (349, 'Battery Electric Veh', 'MODEL Y'),
#  (350, 'Battery Electric Veh', 'E-TRON'),
#  (351, 'Battery Electric Veh', 'E-TRON'),
#  (352, 'Battery Electric Veh', 'MODEL S'),
#  (353, 'Battery Electric Veh', 'BOLT EV'),
#  (354, 'Battery Electric Veh', 'LEAF'),
#  (355, 'Battery Electric Veh', 'LEAF'),
#  (356, 'Plug-in Hybrid Elect', 'VOLT'),
#  (357, 'Battery Electric Veh', 'EV6'),
#  (358, 'Battery Electric Veh', 'BOLT EV'),
#  (359, 'Battery Electric Veh', 'MODEL 3'),
#  (360, 'Battery Electric Veh', 'R1T'),
#  (361, 'Battery Electric Veh', 'NIRO'),
#  (362, 'Battery Electric Veh', 'ID.4'),
#  (363, 'Battery Electric Veh', 'LEAF'),
#  (364, 'Battery Electric Veh', 'MODEL Y'),
#  (365, 'Battery Electric Veh', 'LEAF'),
#  (366, 'Battery Electric Veh', 'MODEL Y'),
#  (367, 'Battery Electric Veh', 'BOLT EV'),
#  (368, 'Battery Electric Veh', 'MODEL 3'),
#  (369, 'Battery Electric Veh', 'MODEL 3'),
#  (370, 'Battery Electric Veh', 'MODEL Y'),
#  (371, 'Battery Electric Veh', 'MODEL 3'),
#  (372, 'Battery Electric Veh', 'LEAF'),
#  (373, 'Battery Electric Veh', 'EQS-CLASS SEDAN'),
#  (374, 'Battery Electric Veh', 'MODEL Y'),
#  (375, 'Battery Electric Veh', 'MODEL S'),
#  (376, 'Battery Electric Veh', 'MODEL Y'),
#  (377, 'Plug-in Hybrid Elect', 'PRIUS PLUG-IN'),
#  (378, 'Battery Electric Veh', 'MODEL Y'),
#  (379, 'Battery Electric Veh', 'MODEL Y'),
#  (380, 'Plug-in Hybrid Elect', 'XC60'),
#  (381, 'Battery Electric Veh', 'MODEL S'),
#  (382, 'Battery Electric Veh', 'MODEL Y'),
#  (383, 'Battery Electric Veh', 'MODEL S'),
#  (384, 'Battery Electric Veh', 'LEAF'),
#  (385, 'Plug-in Hybrid Elect', 'C-MAX'),
#  (386, 'Battery Electric Veh', 'LEAF'),
#  (387, 'Battery Electric Veh', 'LEAF'),
#  (388, 'Battery Electric Veh', 'MODEL 3'),
#  (389, 'Battery Electric Veh', 'MODEL 3'),
#  (390, 'Plug-in Hybrid Elect', 'PRIUS PRIME'),
#  (391, 'Battery Electric Veh', 'MODEL Y'),
#  (392, 'Battery Electric Veh', 'MODEL Y'),
#  (393, 'Plug-in Hybrid Elect', 'RAV4 PRIME'),
#  (394, 'Battery Electric Veh', 'MODEL Y'),
#  (395, 'Battery Electric Veh', 'SOUL EV'),
#  (396, 'Battery Electric Veh', 'MODEL Y'),
#  (397, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (398, 'Battery Electric Veh', 'R1S'),
#  (399, 'Battery Electric Veh', 'MODEL 3'),
#  (400, 'Battery Electric Veh', 'EV6'),
#  (401, 'Plug-in Hybrid Elect', 'XC60'),
#  (402, 'Battery Electric Veh', 'MODEL Y'),
#  (403, 'Battery Electric Veh', 'BOLT EV'),
#  (404, 'Battery Electric Veh', 'MODEL X'),
#  (405, 'Plug-in Hybrid Elect', 'PACIFICA'),
#  (406, 'Battery Electric Veh', 'LEAF'),
#  (407, 'Battery Electric Veh', 'LEAF'),
#  (408, 'Battery Electric Veh', 'LEAF'),
#  (409, 'Battery Electric Veh', 'MODEL Y'),
#  (410, 'Battery Electric Veh', 'SOUL'),
#  (411, 'Battery Electric Veh', 'KONA ELECTRIC'),
#  (412, 'Battery Electric Veh', 'IX'),
#  (413, 'Plug-in Hybrid Elect', 'NIRO'),
#  (414, 'Battery Electric Veh', 'MODEL Y'),
#  (415, 'Battery Electric Veh', 'MODEL 3'),
#  (416, 'Battery Electric Veh', 'MODEL Y'),
#  (417, 'Battery Electric Veh', 'LEAF'),
#  (418, 'Battery Electric Veh', 'KONA'),
#  (419, 'Battery Electric Veh', 'LEAF'),
#  (420, 'Battery Electric Veh', 'MODEL Y'),
#  (421, 'Battery Electric Veh', 'LEAF'),
#  (422, 'Battery Electric Veh', 'MODEL Y'),
#  (423, 'Battery Electric Veh', 'MODEL 3'),
#  (424, 'Battery Electric Veh', 'IX'),
#  (425, 'Battery Electric Veh', 'MODEL Y'),
#  (426, 'Battery Electric Veh', 'E-GOLF'),
#  (427, 'Battery Electric Veh', 'MODEL 3'),
#  (428, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (429, 'Battery Electric Veh', 'MODEL Y'),
#  (430, 'Battery Electric Veh', 'MODEL Y'),
#  (431, 'Plug-in Hybrid Elect', 'Q5 E'),
#  (432, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (433, 'Battery Electric Veh', 'BOLT EV'),
#  (434, 'Plug-in Hybrid Elect', 'VOLT'),
#  (435, 'Battery Electric Veh', 'MODEL 3'),
#  (436, 'Battery Electric Veh', 'LEAF'),
#  (437, 'Battery Electric Veh', 'MODEL Y'),
#  (438, 'Battery Electric Veh', 'MODEL 3'),
#  (439, 'Battery Electric Veh', 'LEAF'),
#  (440, 'Battery Electric Veh', 'MODEL S'),
#  (441, 'Battery Electric Veh', 'MODEL Y'),
#  (442, 'Battery Electric Veh', 'MODEL 3'),
#  (443, 'Battery Electric Veh', 'BOLT EV'),
#  (444, 'Plug-in Hybrid Elect', 'PRIUS PRIME'),
#  (445, 'Plug-in Hybrid Elect', 'RAV4 PRIME'),
#  (446, 'Battery Electric Veh', 'MODEL 3'),
#  (447, 'Battery Electric Veh', 'MODEL Y'),
#  (448, 'Plug-in Hybrid Elect', 'PACIFICA'),
#  (449, 'Battery Electric Veh', 'MODEL S'),
#  (450, 'Battery Electric Veh', 'MODEL 3'),
#  (451, 'Plug-in Hybrid Elect', 'C-MAX'),
#  (452, 'Battery Electric Veh', 'LEAF'),
#  (453, 'Battery Electric Veh', 'MODEL Y'),
#  (454, 'Plug-in Hybrid Elect', 'I3'),
#  (455, 'Battery Electric Veh', 'MODEL Y'),
#  (456, 'Battery Electric Veh', 'MODEL 3'),
#  (457, 'Battery Electric Veh', 'MODEL 3'),
#  (458, 'Battery Electric Veh', 'MODEL 3'),
#  (459, 'Battery Electric Veh', 'MODEL S'),
#  (460, 'Battery Electric Veh', 'MODEL 3'),
#  (461, 'Plug-in Hybrid Elect', 'I3'),
#  (462, 'Battery Electric Veh', 'LEAF'),
#  (463, 'Battery Electric Veh', 'MODEL S'),
#  (464, 'Battery Electric Veh', 'LEAF'),
#  (465, 'Plug-in Hybrid Elect', 'I3'),
#  (466, 'Battery Electric Veh', 'MODEL X'),
#  (467, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (468, 'Battery Electric Veh', 'MODEL 3'),
#  (469, 'Battery Electric Veh', 'LEAF'),
#  (470, 'Battery Electric Veh', 'MODEL 3'),
#  (471, 'Battery Electric Veh', 'BOLT EUV'),
#  (472, 'Battery Electric Veh', 'MODEL 3'),
#  (473, 'Battery Electric Veh', 'R1T'),
#  (474, 'Battery Electric Veh', 'EV6'),
#  (475, 'Plug-in Hybrid Elect', 'I8'),
#  (476, 'Plug-in Hybrid Elect', 'RAV4 PRIME'),
#  (477, 'Plug-in Hybrid Elect', 'I3'),
#  (478, 'Battery Electric Veh', 'LEAF'),
#  (479, 'Battery Electric Veh', 'MODEL Y'),
#  (480, 'Battery Electric Veh', 'FORTWO ELECTRIC DRIV'),
#  (481, 'Battery Electric Veh', 'MODEL Y'),
#  (482, 'Plug-in Hybrid Elect', 'VOLT'),
#  (483, 'Plug-in Hybrid Elect', 'PACIFICA'),
#  (484, 'Plug-in Hybrid Elect', 'XC90'),
#  (485, 'Battery Electric Veh', 'MODEL 3'),
#  (486, 'Battery Electric Veh', 'MODEL Y'),
#  (487, 'Battery Electric Veh', 'MODEL 3'),
#  (488, 'Plug-in Hybrid Elect', 'FUSION'),
#  (489, 'Battery Electric Veh', 'MODEL 3'),
#  (490, 'Battery Electric Veh', 'MODEL Y'),
#  (491, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (492, 'Plug-in Hybrid Elect', 'VOLT'),
#  (493, 'Battery Electric Veh', 'ID.4'),
#  (494, 'Battery Electric Veh', 'MODEL 3'),
#  (495, 'Battery Electric Veh', 'MODEL 3'),
#  (496, 'Battery Electric Veh', 'MODEL Y'),
#  (497, 'Battery Electric Veh', 'MODEL X'),
#  (498, 'Plug-in Hybrid Elect', 'PRIUS PRIME'),
#  (499, 'Battery Electric Veh', 'LEAF'),
#  (500, 'Plug-in Hybrid Elect', 'PACIFICA'),
#  (501, 'Battery Electric Veh', 'LEAF'),
#  (502, 'Battery Electric Veh', 'MODEL S'),
#  (503, 'Battery Electric Veh', 'MODEL Y'),
#  (504, 'Battery Electric Veh', 'MODEL Y'),
#  (505, 'Plug-in Hybrid Elect', '330E'),
#  (506, 'Battery Electric Veh', 'MODEL Y'),
#  (507, 'Battery Electric Veh', 'MODEL 3'),
#  (508, 'Battery Electric Veh', 'LEAF'),
#  (509, 'Battery Electric Veh', 'MODEL 3'),
#  (510, 'Battery Electric Veh', 'EQS-CLASS SEDAN'),
#  (511, 'Battery Electric Veh', 'NIRO'),
#  (512, 'Plug-in Hybrid Elect', 'VOLT'),
#  (513, 'Plug-in Hybrid Elect', 'X3'),
#  (514, 'Plug-in Hybrid Elect', 'X5'),
#  (515, 'Plug-in Hybrid Elect', 'RAV4 PRIME'),
#  (516, 'Battery Electric Veh', 'LEAF'),
#  (517, 'Battery Electric Veh', 'MODEL S'),
#  (518, 'Plug-in Hybrid Elect', 'VOLT'),
#  (519, 'Battery Electric Veh', 'NIRO'),
#  (520, 'Battery Electric Veh', 'MODEL 3'),
#  (521, 'Plug-in Hybrid Elect', 'COUNTRYMAN'),
#  (522, 'Battery Electric Veh', 'MODEL X'),
#  (523, 'Battery Electric Veh', 'MODEL Y'),
#  (524, 'Battery Electric Veh', 'LEAF'),
#  (525, 'Plug-in Hybrid Elect', 'WRANGLER'),
#  (526, 'Battery Electric Veh', 'R1S'),
#  (527, 'Battery Electric Veh', 'BOLT EV'),
#  (528, 'Plug-in Hybrid Elect', 'NIRO'),
#  (529, 'Battery Electric Veh', 'EV6'),
#  (530, 'Battery Electric Veh', 'MODEL Y'),
#  (531, 'Battery Electric Veh', 'MODEL X'),
#  (532, 'Battery Electric Veh', 'MODEL Y'),
#  (533, 'Plug-in Hybrid Elect', 'PRIUS PRIME'),
#  (534, 'Carretera', 'Canada'),
#  (535, 'Carretera', 'Germany'),
#  (536, 'Carretera', 'France'),
#  (537, 'Carretera', 'Germany'),
#  (538, 'Carretera', 'Mexico'),
#  (539, 'Carretera', 'Germany'),
#  (540, 'Montana', 'Germany'),
#  (541, 'Montana', 'Canada'),
#  (542, 'Montana', 'France'),
#  (543, 'Montana', 'Germany'),
#  (544, 'Montana', 'Mexico'),
#  (545, 'Montana', 'Canada'),
#  (546, 'Montana', 'Mexico'),
#  (547, 'Montana', 'Germany'),
#  (548, 'Montana', 'Canada'),
#  (549, 'Montana', 'United States of Ame'),
#  (550, 'Paseo', 'Canada'),
#  (551, 'Paseo', 'Mexico'),
#  (552, 'Paseo', 'Canada'),
#  (553, 'Paseo', 'Germany'),
#  (554, 'Paseo', 'Germany'),
#  (555, 'Paseo', 'Mexico'),
#  (556, 'Paseo', 'France'),
#  (557, 'Paseo', 'Mexico'),
#  (558, 'Paseo', 'Mexico'),
#  (559, 'Paseo', 'United States of Ame'),
#  (560, 'Paseo', 'Canada'),
#  (561, 'Paseo', 'United States of Ame'),
#  (562, 'Paseo', 'Canada'),
#  (563, 'Paseo', 'Canada'),
#  (564, 'Paseo', 'Germany'),
#  (565, 'Velo', 'Mexico'),
#  (566, 'Velo', 'France'),
#  (567, 'Velo', 'Germany'),
#  (568, 'Velo', 'Germany'),
#  (569, 'Velo', 'Germany'),
#  (570, 'Velo', 'United States of Ame'),
#  (571, 'Velo', 'Canada'),
#  (572, 'VTT', 'Canada'),
#  (573, 'VTT', 'Germany'),
#  (574, 'VTT', 'France'),
#  (575, 'VTT', 'Germany'),
#  (576, 'VTT', 'France'),
#  (577, 'VTT', 'France'),
#  (578, 'VTT', 'Canada'),
#  (579, 'Amarilla', 'France'),
#  (580, 'Amarilla', 'United States of Ame'),
#  (581, 'Amarilla', 'Germany'),
#  (582, 'Amarilla', 'France'),
#  (583, 'Amarilla', 'Germany'),
#  (584, 'Amarilla', 'United States of Ame'),
#  (585, 'Amarilla', 'United States of Ame'),
#  (586, 'Amarilla', 'United States of Ame'),
#  (587, 'Paseo', 'France'),
#  (588, 'Paseo', 'France'),
#  (589, 'Paseo', 'France'),
#  (590, 'Velo', 'France'),
#  (591, 'VTT', 'Canada'),
#  (592, 'Carretera', 'United States of Ame'),
#  (593, 'Carretera', 'Mexico'),
#  (594, 'Carretera', 'United States of Ame'),
#  (595, 'Carretera', 'Canada'),
#  (596, 'Carretera', 'United States of Ame'),
#  (597, 'Carretera', 'France'),
#  (598, 'Carretera', 'Germany'),
#  (599, 'Carretera', 'Mexico'),
#  (600, 'Carretera', 'Mexico'),
#  (601, 'Carretera', 'France'),
#  (602, 'Montana', 'Mexico'),
#  (603, 'Montana', 'United States of Ame'),
#  (604, 'Montana', 'France'),
#  (605, 'Montana', 'Canada'),
#  (606, 'Montana', 'United States of Ame'),
#  (607, 'Montana', 'United States of Ame'),
#  (608, 'Paseo', 'United States of Ame'),
#  (609, 'Paseo', 'United States of Ame'),
#  (610, 'Paseo', 'United States of Ame'),
#  (611, 'Paseo', 'France'),
#  (612, 'Paseo', 'Mexico'),
#  (613, 'Paseo', 'Germany'),
#  (614, 'Paseo', 'Germany'),
#  (615, 'Paseo', 'United States of Ame'),
#  (616, 'Paseo', 'France'),
#  (617, 'Velo', 'France'),
#  (618, 'Velo', 'Mexico'),
#  (619, 'Velo', 'Canada'),
#  (620, 'Velo', 'United States of Ame'),
#  (621, 'Velo', 'Canada'),
#  (622, 'VTT', 'Germany'),
#  (623, 'VTT', 'Canada'),
#  (624, 'VTT', 'United States of Ame'),
#  (625, 'VTT', 'France'),
#  (626, 'VTT', 'Germany'),
#  (627, 'VTT', 'Mexico'),
#  (628, 'VTT', 'Mexico'),
#  (629, 'VTT', 'France'),
#  (630, 'Amarilla', 'United States of Ame'),
#  (631, 'Amarilla', 'France'),
#  (632, 'Carretera', 'Canada'),
#  (633, 'Carretera', 'Canada'),
#  (634, 'Carretera', 'Germany'),
#  (635, 'Carretera', 'France'),
#  (636, 'Carretera', 'Canada'),
#  (637, 'Montana', 'United States of Ame'),
#  (638, 'Montana', 'United States of Ame'),
#  (639, 'Montana', 'Mexico'),
#  (640, 'Montana', 'Mexico'),
#  (641, 'Paseo', 'Canada'),
#  (642, 'Paseo', 'France'),
#  (643, 'Paseo', 'Germany'),
#  (644, 'Paseo', 'United States of Ame'),
#  (645, 'Paseo', 'Mexico'),
#  (646, 'Paseo', 'Canada'),
#  (647, 'Paseo', 'Germany'),
#  (648, 'Paseo', 'Mexico'),
#  (649, 'Paseo', 'France'),
#  (650, 'Paseo', 'Canada'),
#  (651, 'Paseo', 'Canada'),
#  (652, 'Paseo', 'Canada'),
#  (653, 'Paseo', 'United States of Ame'),
#  (654, 'Paseo', 'United States of Ame'),
#  (655, 'Paseo', 'France'),
#  (656, 'Paseo', 'Mexico'),
#  (657, 'Velo', 'United States of Ame'),
#  (658, 'Velo', 'Germany'),
#  (659, 'Velo', 'Germany'),
#  (660, 'Velo', 'Germany'),
#  (661, 'Velo', 'Mexico'),
#  (662, 'Velo', 'France'),
#  (663, 'Velo', 'Mexico'),
#  (664, 'Velo', 'Mexico'),
#  (665, 'VTT', 'Mexico'),
#  (666, 'VTT', 'Germany'),
#  (667, 'VTT', 'Germany'),
#  (668, 'VTT', 'Canada'),
#  (669, 'VTT', 'United States of Ame'),
#  (670, 'VTT', 'Mexico'),
#  (671, 'Amarilla', 'Germany'),
#  (672, 'Amarilla', 'Mexico'),
#  (673, 'Amarilla', 'Germany'),
#  (674, 'Amarilla', 'Germany'),
#  (675, 'Amarilla', 'United States of Ame'),
#  (676, 'Amarilla', 'France'),
#  (677, 'Amarilla', 'Canada'),
#  (678, 'Carretera', 'France'),
#  (679, 'Carretera', 'Germany'),
#  (680, 'Carretera', 'Germany'),
#  (681, 'Carretera', 'United States of Ame'),
#  (682, 'Carretera', 'Canada'),
#  (683, 'Montana', 'Germany'),
#  (684, 'Montana', 'France'),
#  (685, 'Montana', 'France'),
#  (686, 'Montana', 'Germany'),
#  (687, 'Montana', 'France'),
#  (688, 'Montana', 'Germany'),
#  (689, 'Paseo', 'France'),
#  (690, 'Paseo', 'Canada'),
#  (691, 'Paseo', 'France'),
#  (692, 'Paseo', 'Germany'),
#  (693, 'Paseo', 'Germany'),
#  (694, 'Paseo', 'United States of Ame'),
#  (695, 'Paseo', 'Canada'),
#  (696, 'Paseo', 'Germany'),
#  (697, 'Paseo', 'France'),
#  (698, 'Paseo', 'Germany'),
#  (699, 'Velo', 'Canada'),
#  (700, 'VTT', 'United States of Ame'),
#  (701, 'VTT', 'Mexico'),
#  (702, 'VTT', 'Germany'),
#  (703, 'VTT', 'Canada'),
#  (704, 'VTT', 'Mexico'),
#  (705, 'VTT', 'Germany'),
#  (706, 'Carretera', 'Canada'),
#  (707, 'Paseo', 'Mexico'),
#  (708, 'Velo', 'Canada'),
#  (709, 'VTT', 'Germany'),
#  (710, 'Montana', 'Mexico'),
#  (711, 'Paseo', 'Mexico'),
#  (712, 'Paseo', 'France'),
#  (713, 'Velo', 'United States of Ame'),
#  (714, 'Carretera', 'Canada'),
#  (715, 'Carretera', 'Germany'),
#  (716, 'Carretera', 'United States of Ame'),
#  (717, 'Montana', 'Canada'),
#  (718, 'Montana', 'Germany'),
#  (719, 'Montana', 'Canada'),
#  (720, 'Montana', 'Germany'),
#  (721, 'Montana', 'Mexico'),
#  (722, 'Paseo', 'Canada'),
#  (723, 'Paseo', 'Germany'),
#  (724, 'Paseo', 'Germany'),
#  (725, 'Paseo', 'United States of Ame'),
#  (726, 'Paseo', 'United States of Ame'),
#  (727, 'Paseo', 'France'),
#  (728, 'Paseo', 'Canada'),
#  (729, 'Paseo', 'Canada'),
#  (730, 'Paseo', 'United States of Ame'),
#  (731, 'Paseo', 'United States of Ame'),
#  (732, 'Paseo', 'Mexico'),
#  (733, 'Paseo', 'United States of Ame'),
#  (734, 'Paseo', 'Mexico'),
#  (735, 'Velo', 'United States of Ame'),
#  (736, 'Velo', 'Canada'),
#  (737, 'Velo', 'France'),
#  (738, 'VTT', 'France'),
#  (739, 'VTT', 'United States of Ame'),
#  (740, 'VTT', 'France'),
#  (741, 'VTT', 'Mexico'),
#  (742, 'Amarilla', 'Mexico'),
#  (743, 'Amarilla', 'Mexico'),
#  (744, 'Amarilla', 'Germany'),
#  (745, 'Amarilla', 'United States of Ame'),
#  (746, 'Amarilla', 'Canada'),
#  (747, 'Montana', 'Germany'),
#  (748, 'Paseo', 'Germany'),
#  (749, 'Paseo', 'Canada'),
#  (750, 'Paseo', 'Mexico'),
#  (751, 'Paseo', 'Canada'),
#  (752, 'Velo', 'Canada'),
#  (753, 'VTT', 'Mexico'),
#  (754, 'Amarilla', 'Mexico'),
#  (755, 'Amarilla', 'Mexico'),
#  (756, 'Amarilla', 'Germany'),
#  (757, 'Carretera', 'France'),
#  (758, 'Carretera', 'Germany'),
#  (759, 'Carretera', 'France'),
#  (760, 'Carretera', 'United States of Ame'),
#  (761, 'Carretera', 'Germany'),
#  (762, 'Carretera', 'Mexico'),
#  (763, 'Carretera', 'United States of Ame'),
#  (764, 'Carretera', 'France'),
#  (765, 'Montana', 'France'),
#  (766, 'Montana', 'United States of Ame'),
#  (767, 'Montana', 'Mexico'),
#  (768, 'Montana', 'Germany'),
#  (769, 'Montana', 'Mexico'),
#  (770, 'Paseo', 'France'),
#  (771, 'Paseo', 'United States of Ame'),
#  (772, 'Paseo', 'France'),
#  (773, 'Paseo', 'Mexico'),
#  (774, 'Paseo', 'United States of Ame'),
#  (775, 'Paseo', 'United States of Ame'),
#  (776, 'Paseo', 'United States of Ame'),
#  (777, 'Paseo', 'France'),
#  (778, 'Paseo', 'Canada'),
#  (779, 'Paseo', 'Canada'),
#  (780, 'Paseo', 'United States of Ame'),
#  (781, 'Paseo', 'France'),
#  (782, 'Paseo', 'Canada'),
#  (783, 'Paseo', 'United States of Ame'),
#  (784, 'Paseo', 'France'),
#  (785, 'Paseo', 'Germany'),
#  (786, 'Velo', 'United States of Ame'),
#  (787, 'Velo', 'Mexico'),
#  (788, 'Velo', 'Germany'),
#  (789, 'Velo', 'United States of Ame'),
#  (790, 'Velo', 'United States of Ame'),
#  (791, 'Velo', 'France'),
#  (792, 'Velo', 'United States of Ame'),
#  (793, 'Velo', 'France'),
#  (794, 'Velo', 'France'),
#  (795, 'Velo', 'Germany'),
#  (796, 'VTT', 'Canada'),
#  (797, 'VTT', 'United States of Ame'),
#  (798, 'VTT', 'Germany'),
#  (799, 'VTT', 'United States of Ame'),
#  (800, 'VTT', 'United States of Ame'),
#  (801, 'VTT', 'France'),
#  (802, 'Amarilla', 'Germany'),
#  (803, 'Amarilla', 'Canada'),
#  (804, 'Amarilla', 'Canada'),
#  (805, 'Amarilla', 'Germany'),
#  (806, 'Paseo', 'France'),
#  (807, 'Carretera', 'United States of Ame'),
#  (808, 'Carretera', 'Canada'),
#  (809, 'Carretera', 'Mexico'),
#  (810, 'Carretera', 'Canada'),
#  (811, 'Carretera', 'United States of Ame'),
#  (812, 'Carretera', 'United States of Ame'),
#  (813, 'Carretera', 'Germany'),
#  (814, 'Montana', 'Mexico'),
#  (815, 'Montana', 'Germany'),
#  (816, 'Montana', 'France'),
#  (817, 'Montana', 'United States of Ame'),
#  (818, 'Paseo', 'France'),
#  (819, 'Paseo', 'Canada'),
#  (820, 'Paseo', 'United States of Ame'),
#  (821, 'Velo', 'Canada'),
#  (822, 'Velo', 'United States of Ame'),
#  (823, 'Velo', 'Germany'),
#  (824, 'Velo', 'France'),
#  (825, 'Velo', 'Mexico'),
#  (826, 'Velo', 'France'),
#  (827, 'Velo', 'France'),
#  (828, 'VTT', 'Canada'),
#  (829, 'VTT', 'Mexico'),
#  (830, 'VTT', 'France'),
#  (831, 'VTT', 'Mexico'),
#  (832, 'VTT', 'Canada'),
#  (833, 'Amarilla', 'France'),
#  (834, 'Amarilla', 'Mexico'),
#  (835, 'Amarilla', 'United States of Ame'),
#  (836, 'Amarilla', 'France'),
#  (837, 'Amarilla', 'France'),
#  (838, 'Montana', 'France'),
#  (839, 'Paseo', 'United States of Ame'),
#  (840, 'Paseo', 'Germany'),
#  (841, 'Paseo', 'United States of Ame'),
#  (842, 'Paseo', 'France'),
#  (843, 'Velo', 'Germany'),
#  (844, 'Velo', 'Mexico'),
#  (845, 'VTT', 'United States of Ame'),
#  (846, 'Carretera', 'Mexico'),
#  (847, 'Carretera', 'Canada'),
#  (848, 'Carretera', 'Mexico'),
#  (849, 'Montana', 'Mexico'),
#  (850, 'Montana', 'France'),
#  (851, 'Paseo', 'France'),
#  (852, 'Velo', 'Canada'),
#  (853, 'Velo', 'Canada'),
#  (854, 'Velo', 'United States of Ame'),
#  (855, 'Velo', 'Canada'),
#  (856, 'VTT', 'France'),
#  (857, 'VTT', 'Germany'),
#  (858, 'VTT', 'Canada'),
#  (859, 'Amarilla', 'Canada'),
#  (860, 'Carretera', 'United States of Ame'),
#  (861, 'Carretera', 'France'),
#  (862, 'Carretera', 'France'),
#  (863, 'Montana', 'France'),
#  (864, 'Montana', 'France'),
#  (865, 'Montana', 'Germany'),
#  (866, 'Paseo', 'Canada'),
#  (867, 'Paseo', 'France'),
#  (868, 'Paseo', 'Germany'),
#  (869, 'Paseo', 'France'),
#  (870, 'Paseo', 'United States of Ame'),
#  (871, 'Paseo', 'France'),
#  (872, 'Paseo', 'Germany'),
#  (873, 'Paseo', 'Canada'),
#  (874, 'Paseo', 'Mexico'),
#  (875, 'Paseo', 'Germany'),
#  (876, 'Velo', 'France'),
#  (877, 'Velo', 'Mexico'),
#  (878, 'Velo', 'Germany'),
#  (879, 'Velo', 'France'),
#  (880, 'Velo', 'United States of Ame'),
#  (881, 'Velo', 'United States of Ame'),
#  (882, 'Velo', 'Germany'),
#  (883, 'VTT', 'Canada'),
#  (884, 'VTT', 'France'),
#  (885, 'VTT', 'Mexico'),
#  (886, 'Amarilla', 'Canada'),
#  (887, 'Amarilla', 'France'),
#  (888, 'Amarilla', 'Germany'),
#  (889, 'Amarilla', 'Canada'),
#  (890, 'Amarilla', 'United States of Ame'),
#  (891, 'Montana', 'Canada'),
#  (892, 'Montana', 'United States of Ame'),
#  (893, 'Paseo', 'Canada'),
#  (894, 'Amarilla', 'United States of Ame'),
#  (895, 'Carretera', 'Mexico'),
#  (896, 'Carretera', 'France'),
#  (897, 'Carretera', 'Mexico'),
#  (898, 'Montana', 'France'),
#  (899, 'Montana', 'Canada'),
#  (900, 'Montana', 'Germany'),
#  (901, 'Montana', 'France'),
#  (902, 'Montana', 'Canada'),
#  (903, 'Montana', 'Germany'),
#  (904, 'Paseo', 'Mexico'),
#  (905, 'Paseo', 'Germany'),
#  (906, 'Paseo', 'Germany'),
#  (907, 'Paseo', 'Germany'),
#  (908, 'Paseo', 'Mexico'),
#  (909, 'Paseo', 'United States of Ame'),
#  (910, 'Paseo', 'Germany'),
#  (911, 'Paseo', 'Germany'),
#  (912, 'Paseo', 'Germany'),
#  (913, 'Paseo', 'Mexico'),
#  (914, 'Paseo', 'Germany'),
#  (915, 'Paseo', 'Mexico'),
#  (916, 'Paseo', 'Mexico'),
#  (917, 'Velo', 'Canada'),
#  (918, 'Velo', 'United States of Ame'),
#  (919, 'Velo', 'Germany'),
#  (920, 'Velo', 'France'),
#  (921, 'Velo', 'Mexico'),
#  (922, 'VTT', 'France'),
#  (923, 'VTT', 'Germany'),
#  (924, 'VTT', 'France'),
#  (925, 'VTT', 'Germany'),
#  (926, 'VTT', 'Canada'),
#  (927, 'VTT', 'United States of Ame'),
#  (928, 'Amarilla', 'Canada'),
#  (929, 'Amarilla', 'United States of Ame'),
#  (930, 'Amarilla', 'Germany'),
#  (931, 'Amarilla', 'Mexico'),
#  (932, 'Amarilla', 'Germany'),
#  (933, 'Amarilla', 'Germany'),
#  (934, 'Amarilla', 'Mexico'),
#  (935, 'Amarilla', 'Mexico'),
#  (936, 'VTT', 'United States of Ame'),
#  (937, 'Carretera', 'Canada'),
#  (938, 'Carretera', 'Mexico'),
#  (939, 'Montana', 'Canada'),
#  (940, 'Montana', 'France'),
#  (941, 'Montana', 'France'),
#  (942, 'Montana', 'Canada'),
#  (943, 'Montana', 'France'),
#  (944, 'Montana', 'Canada'),
#  (945, 'Montana', 'United States of Ame'),
#  (946, 'Montana', 'Germany'),
#  (947, 'Paseo', 'Mexico'),
#  (948, 'Paseo', 'Mexico'),
#  (949, 'Paseo', 'United States of Ame'),
#  (950, 'Paseo', 'Canada'),
#  (951, 'Paseo', 'France'),
#  (952, 'Paseo', 'Mexico'),
#  (953, 'Paseo', 'France'),
#  (954, 'Paseo', 'Germany'),
#  (955, 'Paseo', 'United States of Ame'),
#  (956, 'Velo', 'Mexico'),
#  (957, 'Velo', 'Canada'),
#  (958, 'Velo', 'Germany'),
#  (959, 'Velo', 'Canada'),
#  (960, 'Velo', 'Mexico'),
#  (961, 'Velo', 'Canada'),
#  (962, 'VTT', 'United States of Ame'),
#  (963, 'VTT', 'Germany'),
#  (964, 'VTT', 'United States of Ame'),
#  (965, 'VTT', 'Germany'),
#  (966, 'VTT', 'United States of Ame'),
#  (967, 'VTT', 'France'),
#  (968, 'VTT', 'France'),
#  (969, 'VTT', 'Mexico'),
#  (970, 'Amarilla', 'United States of Ame'),
#  (971, 'Amarilla', 'Canada'),
#  (972, 'Amarilla', 'Germany'),
#  (973, 'Amarilla', 'Mexico'),
#  (974, 'Carretera', 'Germany'),
#  (975, 'Carretera', 'Canada'),
#  (976, 'Carretera', 'Germany'),
#  (977, 'Carretera', 'Mexico'),
#  (978, 'Paseo', 'United States of Ame'),
#  (979, 'Paseo', 'Mexico'),
#  (980, 'Paseo', 'Germany'),
#  (981, 'Velo', 'France'),
#  (982, 'Velo', 'Mexico'),
#  (983, 'VTT', 'Germany'),
#  (984, 'VTT', 'France'),
#  (985, 'VTT', 'Mexico'),
#  (986, 'Amarilla', 'Mexico'),
#  (987, 'Amarilla', 'Canada'),
#  (988, 'Amarilla', 'France'),
#  (989, 'Carretera', 'United States of Ame'),
#  (990, 'Montana', 'United States of Ame'),
#  (991, 'Paseo', 'United States of Ame'),
#  (992, 'Carretera', 'United States of Ame'),
#  (993, 'Carretera', 'France'),
#  (994, 'Montana', 'United States of Ame'),
#  (995, 'Montana', 'United States of Ame'),
#  (996, 'Montana', 'France'),
#  (997, 'Paseo', 'France'),
#  (998, 'Paseo', 'Mexico'),
#  (999, 'Paseo', 'France'),
#  (1000, 'Paseo', 'Germany'),
#  ...]

# %%
# Execute SQL query
cursor.execute("SELECT * FROM product_tb")
# Fetch data and column names
rows = cursor.fetchall()
column_names = [i[0] for i in cursor.description]

# Create DataFrame with column names
ProductData = pd.DataFrame(rows, columns=column_names)

# Display results
ProductData
# Out:
#           p_id                p_name category
# 0            1  Battery Electric Veh  MODEL X
# 1            2  Plug-in Hybrid Elect  CLARITY
# 2            3  Battery Electric Veh  MODEL 3
# 3            4  Battery Electric Veh     LEAF
# 4            5  Battery Electric Veh  MODEL S
# ...        ...                   ...      ...
# 263514  263515  Battery Electric Veh  MODEL Y
# 263515  263516  Battery Electric Veh     LEAF
# 263516  263517  Battery Electric Veh  MODEL Y
# 263517  263518  Battery Electric Veh  MODEL X
# 263518  263519  Battery Electric Veh  MODEL 3
#
# [263519 rows x 3 columns]

# %%
# Execute SQL query
cursor.execute("SELECT * FROM customer_tb")
# Fetch data and column names
rows = cursor.fetchall()
column_names = [i[0] for i in cursor.description]

# Create DataFrame with column names
CustomerData = pd.DataFrame(rows, columns=column_names)

# Display results
CustomerData
# Out:
#       c_id            c_name                  city
# 0        1        Government                Canada
# 1        2        Government               Germany
# 2        3         Midmarket                France
# 3        4         Midmarket               Germany
# 4        5         Midmarket                Mexico
# ...    ...               ...                   ...
# 3495  3496    Small Business                France
# 3496  3497    Small Business                Mexico
# 3497  3498        Government                Mexico
# 3498  3499        Government                Canada
# 3499  3500  Channel Partners  United States of Ame
#
# [3500 rows x 3 columns]

# %%
# Execute SQL query
cursor.execute("SELECT * FROM date_tb")
# Fetch data and column names
rows = cursor.fetchall()
column_names = [i[0] for i in cursor.description]

# Create DataFrame with column names
DateData = pd.DataFrame(rows, columns=column_names)

# Display results
DateData
# Out:
#       d_id  d_date   d_month d_year
# 0        1       1   January   2014
# 1        2       1   January   2014
# 2        3       6      June   2014
# 3        4       6      June   2014
# 4        5       6      June   2014
# ...    ...     ...       ...    ...
# 4893  4896       3     March   2014
# 4894  4897      10   October   2014
# 4895  4898       2  February   2014
# 4896  4899       4     April   2014
# 4897  4900       5       May   2014
#
# [4898 rows x 4 columns]

# %%
date_cols = DateData[['d_id']]
customer_cols = CustomerData[['c_id']]
product_cols = ProductData[['p_id']]
sales_cols = Sales[['quantity','price']]

# %%
concant = pd.concat([date_cols, customer_cols, product_cols, sales_cols], axis=1, join='inner')
concant=concant.rename(columns={'d_id':'Date_id','c_id':'Customer_id','p_id':'Product_id', 'Unit Price':'unit_price'})
concant
# Out:
#      Date_id  Customer_id  Product_id  quantity  price
# 0          1            1           1   32370.0     20
# 1          2            2           2   26420.0     20
# 2          3            3           3   32670.0     15
# 3          4            4           4   13320.0     15
# 4          5            5           5   37050.0     15
# ..       ...          ...         ...       ...    ...
# 695      696          696         696  742500.0    300
# 696      697          697         697  163800.0    300
# 697      698          698         698    9576.0      7
# 698      699          699         699    5061.0      7
# 699      700          700         700   21672.0     12
#
# [700 rows x 5 columns]

# %%
concant.isnull().sum()
# Out:
# Date_id        0
# Customer_id    0
# Product_id     0
# quantity       0
# price          0
# dtype: int64

# %%
insert_query = f"INSERT INTO sale_tb ({','.join(concant.columns)}) VALUES ({','.join(['%s']*len(concant.columns))})"
    
for _, row in concant.iterrows():
    values = tuple(row)
    cursor.execute(insert_query, values)
    
mydb.commit()

# %%
# Execute SQL query
cursor.execute("SELECT * FROM sale_tb")
# Fetch data and column names
rows = cursor.fetchall()
column_names = [i[0] for i in cursor.description]

# Create DataFrame with column names
DateData = pd.DataFrame(rows, columns=column_names)

# Display results
DateData
# Out:
#       transaction_id  customer_id  product_id  date_id  quantity  price
# 0                  5            1           1        1         3     20
# 1                  6            2           2        2         3     20
# 2                  7            3           3        3         3     15
# 3                  8            4           4        4         3     15
# 4                  9            5           5        5         3     15
# ...              ...          ...         ...      ...       ...    ...
# 2795            2800          696         696      696    742500    300
# 2796            2801          697         697      697    163800    300
# 2797            2802          698         698      698      9576      7
# 2798            2803          699         699      699      5061      7
# 2799            2804          700         700      700     21672     12
#
# [2800 rows x 6 columns]
